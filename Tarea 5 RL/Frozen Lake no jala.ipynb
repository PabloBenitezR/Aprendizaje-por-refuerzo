# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

# %%
class FrozenLake_nojala(gym.Env):
    def __init__(self, size=5, trap_prob=0.1, slip_prob=0.1):
        super(FrozenLake_nojala, self).__init__()
        self.size = size
        self.trap_prob = trap_prob
        self.slip_prob = slip_prob
        self.observation_space = spaces.Discrete(size * size)
        self.action_space = spaces.Discrete(4)  
        self.start_pos = (0, 0)
        self.goal_pos = (size - 1, size - 1)
        self.state = self.start_pos
        self.traps = set()
        self.steps = 0

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = self.start_pos
        self.steps = 0
        self._sample_traps()
        return self._get_obs(), {}

    def step(self, action):
        self.steps += 1

        if np.random.rand() < self.slip_prob:
            action = self.action_space.sample()

        # movimiento
        x, y = self.state
        if action == 0 and x > 0:
            x -= 1
        elif action == 1 and y < self.size - 1:
            y += 1
        elif action == 2 and x < self.size - 1:
            x += 1
        elif action == 3 and y > 0:
            y -= 1

        self.state = (x, y)
        terminated = False
        reward = 0.0

        if self.state in self.traps:
            terminated = True
        elif self.state == self.goal_pos:
            reward = 1.0
            terminated = True

        truncated = False
        return self._get_obs(), reward, terminated, truncated, {}

    def _get_obs(self):
        return self.state[0] * self.size + self.state[1]

    def _sample_traps(self):
        self.traps = set()
        num_cells = self.size * self.size
        for i in range(num_cells):
            if np.random.rand() < self.trap_prob:
                cell = (i // self.size, i % self.size)
                if cell != self.start_pos and cell != self.goal_pos:
                    self.traps.add(cell)

    def render(self):
        grid = np.full((self.size, self.size), '.', dtype=str)
        for trap in self.traps:
            grid[trap] = 'X'
        grid[self.goal_pos] = 'G'
        grid[self.state] = 'A'
        print("\n".join([" ".join(row) for row in grid]) + "\n")

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

env = FrozenLake_nojala(size=6, trap_prob=np.random.rand(), slip_prob=np.random.rand())
check_env(env)

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100000)

obs, _ = env.reset()
for _ in range(50):
    action, _ = model.predict(obs)
    obs, reward, done, _, _ = env.step(action)
    env.render()
    if done:
        break
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.62     |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 1354     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.17        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015302431 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -10.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00486    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.00375     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.89        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017844416 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -4.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0139     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.000139    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.61        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010151504 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.0151      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.00848     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.36         |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 702          |
# |    iterations           | 5            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0087297065 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0131      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00791     |
# |    value_loss           | 0.00836      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.25        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008228714 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.0124      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.63         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 7            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0054381974 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -0.397       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0208      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00864     |
# |    value_loss           | 0.00368      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.13        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008720234 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.00917     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.05        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 9           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009363556 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -8.76       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00771    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.0011      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.83        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009495222 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -11.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00243    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00933    |
# |    value_loss           | 0.000295    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.27         |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 11           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0058048405 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.0359       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0105      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.00323      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.3          |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 12           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0075815474 |
# |    clip_fraction        | 0.0691       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00658     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 0.00855      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.96        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010632193 |
# |    clip_fraction        | 0.0937      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.32        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 14          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015211431 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.33         |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 15           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0067520305 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.923       |
# |    explained_variance   | 0.385        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00777      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0088      |
# |    value_loss           | 0.0157       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.88         |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 709          |
# |    iterations           | 16           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0069155544 |
# |    clip_fraction        | 0.0692       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0114      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.36        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 17          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003106047 |
# |    clip_fraction        | 0.0265      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00982    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 0.00923     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.97         |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 18           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0067822123 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.343        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0305      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.00593      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.04        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 19          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004746887 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00799    |
# |    value_loss           | 0.018       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.59        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 20          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004055268 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.728      |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0149     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.0182      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.44         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 21           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0031185334 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0.0904       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0217       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00811     |
# |    value_loss           | 0.00891      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.39        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 22          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009029208 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0096     |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.85        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 23          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006380963 |
# |    clip_fraction        | 0.0843      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0203     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.0163      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.7         |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 24          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004809932 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0199      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 0.0232      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.13        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 25          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006094918 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0121      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.022       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.62       |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 702        |
# |    iterations           | 26         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00623697 |
# |    clip_fraction        | 0.0691     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.554     |
# |    explained_variance   | 0.388      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00315    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0118    |
# |    value_loss           | 0.0267     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.38         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 27           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0077513717 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.0609       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00416     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00837     |
# |    value_loss           | 0.0108       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.29         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 696          |
# |    iterations           | 28           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0057047866 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.024       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 0.0122       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.61        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 694         |
# |    iterations           | 29          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008593634 |
# |    clip_fraction        | 0.0843      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0256     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 0.0138      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.14        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 30          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007947702 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.522      |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00724    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00865    |
# |    value_loss           | 0.0165      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.28         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 691          |
# |    iterations           | 31           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0066391355 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00426      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00765     |
# |    value_loss           | 0.01         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.35        |
# |    ep_rew_mean          | 0.03        |
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 32          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004718149 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0184      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.4         |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 33          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004071489 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00526    |
# |    value_loss           | 0.0218      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.23         |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 687          |
# |    iterations           | 34           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0036755526 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.406       |
# |    explained_variance   | 0.347        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00815     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00582     |
# |    value_loss           | 0.0224       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.22        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 35          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004354654 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00422     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 0.0219      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.19        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 36          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009874695 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.314      |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000727   |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.88        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 37          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004748594 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.25       |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00105    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00512    |
# |    value_loss           | 0.0159      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.8         |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 680         |
# |    iterations           | 38          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.002738438 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.273      |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0291     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 0.019       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.27         |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 39           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0026746383 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | 0.298        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0125      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 0.0258       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.38         |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 40           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0028860655 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000787     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00286     |
# |    value_loss           | 0.0305       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.66       |
# |    ep_rew_mean          | 0.01       |
# | time/                   |            |
# |    fps                  | 678        |
# |    iterations           | 41         |
# |    time_elapsed         | 123        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.00598071 |
# |    clip_fraction        | 0.0413     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.211     |
# |    explained_variance   | 0.168      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0192    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00696   |
# |    value_loss           | 0.0166     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.17         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 42           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0031946627 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.186       |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0163      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00798     |
# |    value_loss           | 0.0179       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 43           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0011934333 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | 0.266        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000212     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00471     |
# |    value_loss           | 0.0209       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.48         |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 680          |
# |    iterations           | 44           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0031902422 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.168       |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00156      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00495     |
# |    value_loss           | 0.0363       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.47         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 680          |
# |    iterations           | 45           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0018702042 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.166       |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.011        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 0.0267       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.6         |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 679         |
# |    iterations           | 46          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.003555897 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.167      |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00303     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00338    |
# |    value_loss           | 0.031       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.11         |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 47           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0015167348 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.171       |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.013       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00525     |
# |    value_loss           | 0.0241       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.81         |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 677          |
# |    iterations           | 48           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0020545847 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.175       |
# |    explained_variance   | 0.34         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00683      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00552     |
# |    value_loss           | 0.0237       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.24         |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 49           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0010226527 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.159       |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000607    |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00474     |
# |    value_loss           | 0.0169       |
# ------------------------------------------
# . A . . . .
# . X . . . X
# X . . . . .
# X . X X . .
# . . . . X .
# . . . . . G
#
# . . . . . .
# . A . . . X
# X . . . . .
# X . X X . .
# . . . . X .
# . . . . . G
