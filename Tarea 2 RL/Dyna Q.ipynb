# %%
import numpy as np
import random
import gymnasium as gym

# %%
env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.1)

# %%
epsilon = 0.1 # tasa de exploración
alpha = 0.1 # tasa de aprendizaje
gamma = 0.99 # factor de descuento
episodios = 1000
max_pasos = 100

# %%
def epsilon_greed1y(Q_valores, epsilon):
    if np.random() < epsilon:
        return np.randint(0, len(Q_valores) - 1 )
    else:
        return np.argmax(Q_valores)

# %%
import numpy as np
import random
import gymnasium as gym

# Parámetros de discretización para MountainCar-v0
NUM_BINS_POS = 10
NUM_BINS_VEL = 10

# Crear los bins para cada dimensión (usamos num_bins+1 para incluir los extremos)
bins_pos = np.linspace(-1.2, 0.6, NUM_BINS_POS + 1)
bins_vel = np.linspace(-0.07, 0.07, NUM_BINS_VEL + 1)

def discretize_state(state, bins_pos, bins_vel):
    """
    Convierte un estado continuo [posición, velocidad] en un índice discreto.
    """
    pos, vel = state
    # np.digitize devuelve índices entre 1 y len(bins)
    pos_bin = np.digitize(pos, bins_pos) - 1
    vel_bin = np.digitize(vel, bins_vel) - 1
    # Asegurarse que el índice no exceda el número de bins - 1
    pos_bin = min(pos_bin, NUM_BINS_POS - 1)
    vel_bin = min(vel_bin, NUM_BINS_VEL - 1)
    # Mapear el par (pos_bin, vel_bin) a un único índice
    return pos_bin * NUM_BINS_VEL + vel_bin

def epsilon_greedy(Q_values, epsilon):
    """
    Selecciona una acción según la política epsilon-greedy.
    
    Parámetros:
      Q_values: vector de valores Q para el estado actual.
      epsilon: probabilidad de explorar.
    """
    if random.random() < epsilon:
        return random.randint(0, len(Q_values) - 1)
    else:
        return np.argmax(Q_values)

def dyna_q(env, num_episodes=500, alpha=0.1, gamma=0.95, epsilon=0.1, planning_steps=5):
    """
    Implementación tabular de Dyna-Q para entornos discretizados.
    
    Parámetros:
      env: entorno Gymnasium.
      num_episodes: número de episodios de entrenamiento.
      alpha: tasa de aprendizaje.
      gamma: factor de descuento.
      epsilon: probabilidad de exploración en la política epsilon-greedy.
      planning_steps: número de actualizaciones de planeación por paso real.
      
    Retorna:
      Q: tabla Q final de forma (n_estados, n_acciones).
    """
    # El total de estados discretos es NUM_BINS_POS * NUM_BINS_VEL
    n_states = NUM_BINS_POS * NUM_BINS_VEL  
    n_actions = env.action_space.n

    # Inicializar Q-table en cero
    Q = np.zeros((n_states, n_actions))
    
    # Inicializar el modelo: model[s][a] = (reward, next_state)
    model = {}
    for s in range(n_states):
        model[s] = {}
        for a in range(n_actions):
            model[s][a] = (0.0, s)  # Valor por defecto

    for episode in range(num_episodes):
        # En Gymnasium el reset devuelve (observacion, info)
        obs, _ = env.reset()
        state = discretize_state(obs, bins_pos, bins_vel)
        done = False

        while not done:
            # Seleccionar acción usando epsilon-greedy
            action = epsilon_greedy(Q[state], epsilon)
            
            # Realizar la acción en el entorno
            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            next_state = discretize_state(next_obs, bins_pos, bins_vel)
            
            # Actualizar Q con la experiencia real (regla de Q-learning)
            best_next_action = np.argmax(Q[next_state])
            Q[state, action] += alpha * (reward + gamma * Q[next_state, best_next_action] - Q[state, action])
            
            # Actualizar el modelo con la transición observada
            model[state][action] = (reward, next_state)
            
            # Fase de planeación: actualizar Q utilizando transiciones almacenadas
            for _ in range(planning_steps):
                # Seleccionar aleatoriamente un estado y acción que ya se hayan visitado
                sampled_state = random.randint(0, n_states - 1)
                sampled_action = random.randint(0, n_actions - 1)
                r_sampled, s_prime_sampled = model[sampled_state][sampled_action]
                best_a_sampled = np.argmax(Q[s_prime_sampled])
                Q[sampled_state, sampled_action] += alpha * (r_sampled + gamma * Q[s_prime_sampled, best_a_sampled]
                                                             - Q[sampled_state, sampled_action])
            
            # Actualizar el estado
            state = next_state
        
        # (Opcional) Puedes imprimir información del episodio
        print(f"Episode {episode+1}/{num_episodes} finalizado.")

    return Q

if __name__ == "__main__":
    # Crear el entorno MountainCar-v0 de Gymnasium
    env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.1)
    
    # Ejecutar el entrenamiento Dyna-Q
    Q_final = dyna_q(env, num_episodes=500, alpha=0.1, gamma=0.99, epsilon=0.1, planning_steps=10)
    print("Tabla Q entrenada (forma):", Q_final.shape)
# Out:
# Episode 1/500 finalizado.
# Episode 2/500 finalizado.
# Episode 3/500 finalizado.
# Episode 4/500 finalizado.
# Episode 5/500 finalizado.
# Episode 6/500 finalizado.
# Episode 7/500 finalizado.
# Episode 8/500 finalizado.
# Episode 9/500 finalizado.
# Episode 10/500 finalizado.
# Episode 11/500 finalizado.
# Episode 12/500 finalizado.
# Episode 13/500 finalizado.
# Episode 14/500 finalizado.
# Episode 15/500 finalizado.
# Episode 16/500 finalizado.
# Episode 17/500 finalizado.
# Episode 18/500 finalizado.
# Episode 19/500 finalizado.
# Episode 20/500 finalizado.
# Episode 21/500 finalizado.
# Episode 22/500 finalizado.
# Episode 23/500 finalizado.
# Episode 24/500 finalizado.
# Episode 25/500 finalizado.
# Episode 26/500 finalizado.
# Episode 27/500 finalizado.
# Episode 28/500 finalizado.
# Episode 29/500 finalizado.
# Episode 30/500 finalizado.
# Episode 31/500 finalizado.
# Episode 32/500 finalizado.
# Episode 33/500 finalizado.
# Episode 34/500 finalizado.
# Episode 35/500 finalizado.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 114
#     111 env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.1)
#     113 # Ejecutar el entrenamiento Dyna-Q
# --> 114 Q_final = dyna_q(env, num_episodes=500, alpha=0.1, gamma=0.99, epsilon=0.1, planning_steps=10)
#     115 print("Tabla Q entrenada (forma):", Q_final.shape)
#
# Cell In[33], line 89, in dyna_q(env, num_episodes, alpha, gamma, epsilon, planning_steps)
#      86 Q[state, action] += alpha * (reward + gamma * Q[next_state, best_next_action] - Q[state, action])
#      88 # Actualizar el modelo con la transición observada
# ---> 89 model[state][action] = (reward, next_state)
#      91 # Fase de planeación: actualizar Q utilizando transiciones almacenadas
#      92 for _ in range(planning_steps):
#      93     # Seleccionar aleatoriamente un estado y acción que ya se hayan visitado
#
# KeyError: -5

# %%
import numpy as np
import random
import gymnasium as gym

# Parámetros de discretización para MountainCar-v0
NUM_BINS_POS = 20
NUM_BINS_VEL = 20

# Crear los bins para cada dimensión (usamos num_bins+1 para incluir los extremos)
bins_pos = np.linspace(-1.2, 0.6, NUM_BINS_POS + 1)
bins_vel = np.linspace(-0.07, 0.07, NUM_BINS_VEL + 1)

def discretize_state(state, bins_pos, bins_vel):
    """
    Convierte un estado continuo [posición, velocidad] en un índice discreto.
    """
    pos, vel = state
    # Obtener el índice y restar 1
    pos_bin = np.digitize(pos, bins_pos) - 1
    vel_bin = np.digitize(vel, bins_vel) - 1
    # Asegurarse de que los índices estén dentro del rango válido usando np.clip
    pos_bin = np.clip(pos_bin, 0, NUM_BINS_POS - 1)
    vel_bin = np.clip(vel_bin, 0, NUM_BINS_VEL - 1)
    # Mapear el par (pos_bin, vel_bin) a un único índice
    return pos_bin * NUM_BINS_VEL + vel_bin

def epsilon_greedy(Q_values, epsilon):
    """
    Selecciona una acción según la política epsilon-greedy.
    
    Parámetros:
      Q_values: vector de valores Q para el estado actual.
      epsilon: probabilidad de explorar.
    """
    if random.random() < epsilon:
        return random.randint(0, len(Q_values) - 1)
    else:
        return np.argmax(Q_values)

def dyna_q(env, num_episodes=500, alpha=0.1, gamma=0.95, epsilon=0.1, planning_steps=5):
    """
    Implementación tabular de Dyna-Q para entornos discretizados.
    
    Parámetros:
      env: entorno Gymnasium.
      num_episodes: número de episodios de entrenamiento.
      alpha: tasa de aprendizaje.
      gamma: factor de descuento.
      epsilon: probabilidad de exploración en la política epsilon-greedy.
      planning_steps: número de actualizaciones de planeación por paso real.
      
    Retorna:
      Q: tabla Q final de forma (n_estados, n_acciones).
    """
    # El total de estados discretos es NUM_BINS_POS * NUM_BINS_VEL
    n_states = NUM_BINS_POS * NUM_BINS_VEL  
    n_actions = env.action_space.n

    # Inicializar Q-table en cero
    Q = np.zeros((n_states, n_actions))
    
    # Inicializar el modelo: model[s][a] = (reward, next_state)
    model = {}
    for s in range(n_states):
        model[s] = {}
        for a in range(n_actions):
            model[s][a] = (0.0, s)  # Valor por defecto

    for episode in range(num_episodes):
        # En Gymnasium el reset devuelve (observacion, info)
        obs, _ = env.reset()
        state = discretize_state(obs, bins_pos, bins_vel)
        done = False

        while not done:
            # Seleccionar acción usando epsilon-greedy
            action = epsilon_greedy(Q[state], epsilon)
            
            # Realizar la acción en el entorno
            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            next_state = discretize_state(next_obs, bins_pos, bins_vel)
            
            # Actualizar Q con la experiencia real (regla de Q-learning)
            best_next_action = np.argmax(Q[next_state])
            Q[state, action] += alpha * (reward + gamma * Q[next_state, best_next_action] - Q[state, action])
            
            # Actualizar el modelo con la transición observada
            model[state][action] = (reward, next_state)
            
            # Fase de planeación: actualizar Q utilizando transiciones almacenadas
            for _ in range(planning_steps):
                # Seleccionar aleatoriamente un estado y acción que ya se hayan visitado
                sampled_state = random.randint(0, n_states - 1)
                sampled_action = random.randint(0, n_actions - 1)
                r_sampled, s_prime_sampled = model[sampled_state][sampled_action]
                best_a_sampled = np.argmax(Q[s_prime_sampled])
                Q[sampled_state, sampled_action] += alpha * (r_sampled + gamma * Q[s_prime_sampled, best_a_sampled]
                                                             - Q[sampled_state, sampled_action])
            
            # Actualizar el estado
            state = next_state
        
        # (Opcional) Puedes imprimir información del episodio
        print(f"Episode {episode+1}/{num_episodes} finalizado.")

    return Q

if __name__ == "__main__":
    # Crear el entorno MountainCar-v0 de Gymnasium
    env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.1)
    
    # Ejecutar el entrenamiento Dyna-Q
    Q_final = dyna_q(env, num_episodes=500, alpha=0.1, gamma=0.99, epsilon=0.1, planning_steps=10)
    print("Tabla Q entrenada (forma):", Q_final.shape)

# %%
import numpy as np
import random
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd

# Parámetros de discretización para MountainCar-v0
NUM_BINS_POS = 20
NUM_BINS_VEL = 20

# Crear los bins para cada dimensión (se usa num_bins+1 para incluir los extremos)
bins_pos = np.linspace(-1.2, 0.6, NUM_BINS_POS + 1)
bins_vel = np.linspace(-0.07, 0.07, NUM_BINS_VEL + 1)

def discretize_state(state, bins_pos, bins_vel):
    """
    Convierte un estado continuo [posición, velocidad] en un índice discreto.
    """
    pos, vel = state
    # Usamos np.clip para asegurarnos que el índice esté dentro de [0, num_bins-1]
    pos_bin = np.clip(np.digitize(pos, bins_pos) - 1, 0, NUM_BINS_POS - 1)
    vel_bin = np.clip(np.digitize(vel, bins_vel) - 1, 0, NUM_BINS_VEL - 1)
    return pos_bin * NUM_BINS_VEL + vel_bin

def epsilon_greedy(Q_values, epsilon):
    """
    Selecciona una acción según la política epsilon-greedy.
    
    Parámetros:
      Q_values: vector de valores Q para el estado actual.
      epsilon: probabilidad de explorar.
    """
    if random.random() < epsilon:
        return random.randint(0, len(Q_values) - 1)
    else:
        return np.argmax(Q_values)

def dyna_q_train(env, num_episodes=500, alpha=0.1, gamma=0.99, epsilon=0.1, planning_steps=10):
    """
    Entrena Dyna-Q en un entorno discretizado.
    
    Retorna:
      Q: la tabla Q aprendida.
      training_rewards: lista con la recompensa total obtenida en cada episodio.
    """
    n_states = NUM_BINS_POS * NUM_BINS_VEL  
    n_actions = env.action_space.n

    Q = np.zeros((n_states, n_actions))
    # Inicializar el modelo: model[s][a] = (reward, next_state)
    model = {s: {a: (0.0, s) for a in range(n_actions)} for s in range(n_states)}
    
    training_rewards = []  # Recompensa total por episodio
    
    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = discretize_state(obs, bins_pos, bins_vel)
        done = False
        total_reward = 0.0
        
        while not done:
            action = epsilon_greedy(Q[state], epsilon)
            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            next_state = discretize_state(next_obs, bins_pos, bins_vel)
            total_reward += reward
            
            # Actualización de Q (Q-learning)
            best_next_action = np.argmax(Q[next_state])
            Q[state, action] += alpha * (reward + gamma * Q[next_state, best_next_action] - Q[state, action])
            
            # Actualizar el modelo con la transición observada
            model[state][action] = (reward, next_state)
            
            # Fase de planeación: actualizar Q utilizando transiciones almacenadas
            for _ in range(planning_steps):
                sampled_state = random.randint(0, n_states - 1)
                sampled_action = random.randint(0, n_actions - 1)
                r_sampled, s_prime_sampled = model[sampled_state][sampled_action]
                best_a_sampled = np.argmax(Q[s_prime_sampled])
                Q[sampled_state, sampled_action] += alpha * (r_sampled + gamma * Q[s_prime_sampled, best_a_sampled]
                                                             - Q[sampled_state, sampled_action])
                
            state = next_state
        
        training_rewards.append(total_reward)
        print(f"Episode {episode+1}/{num_episodes} terminado. Recompensa: {total_reward}")
        
    return Q, training_rewards

def evaluate_policy(env, Q, render=False):
    """
    Evalúa la política resultante (siempre eligiendo la acción greedy)
    y retorna la recompensa total obtenida en un episodio de prueba.
    """
    obs, _ = env.reset()
    state = discretize_state(obs, bins_pos, bins_vel)
    done = False
    total_reward = 0.0
    while not done:
        action = np.argmax(Q[state])  # Política greedy
        next_obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        total_reward += reward
        state = discretize_state(next_obs, bins_pos, bins_vel)
        if render:
            env.render()
    return total_reward

# Parámetros para los experimentos
num_experimentos = 10
num_episodes = 500

# Para almacenar los resultados de cada experimento
all_training_rewards = []  # Lista de listas, una por experimento
evaluation_rewards = []    # Recompensa de evaluación (política greedy) por experimento

# Ejecutar 10 experimentos
for exp in range(num_experimentos):
    print(f"\n=== Experimento {exp+1} ===")
    # Crear un nuevo entorno para cada experimento
    env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.5)
    Q, training_rewards = dyna_q_train(env, num_episodes=num_episodes, alpha=0.01, gamma=0.99, epsilon=0.4, planning_steps=10)
    all_training_rewards.append(training_rewards)
    # Evaluar la política resultante
    eval_reward = evaluate_policy(env, Q)
    evaluation_rewards.append(eval_reward)
    env.close()

# Procesar las recompensas de entrenamiento para graficar
all_training_rewards = np.array(all_training_rewards)  # Dimensión: (num_experimentos, num_episodes)
mean_training_rewards = np.mean(all_training_rewards, axis=0)
std_training_rewards = np.std(all_training_rewards, axis=0)

# Graficar la recompensa promedio durante el entrenamiento
plt.figure(figsize=(10, 5))
episodes = np.arange(1, num_episodes + 1)
plt.plot(episodes, mean_training_rewards, label="Recompensa Promedio")
plt.fill_between(episodes, mean_training_rewards - std_training_rewards, mean_training_rewards + std_training_rewards,
                 alpha=0.2, label="±1 Desv. Estándar")
plt.xlabel("Episodios")
plt.ylabel("Recompensa Total")
plt.title("Curva de Recompensa durante el Entrenamiento (Dyna-Q en MountainCar)")
plt.legend()
plt.show()

# Crear una tabla con los resultados de evaluación
df = pd.DataFrame({
    "Experimento": np.arange(1, num_experimentos + 1),
    "Recompensa Evaluación": evaluation_rewards
})
mean_eval = np.mean(evaluation_rewards)
std_eval = np.std(evaluation_rewards)
summary_df = pd.DataFrame({
    "Media Recompensa": [mean_eval],
    "Desviación Estándar": [std_eval]
})

print("Resultados de Evaluación por Experimento:")
print(df)
print("\nResumen (Media y Desviación Estándar) de la Recompensa Evaluación:")
print(summary_df)
# Out:
# === Experimento 1 ===
# Episode 1/500 terminado. Recompensa: -200.0
# Episode 2/500 terminado. Recompensa: -200.0
# Episode 3/500 terminado. Recompensa: -200.0
# Episode 4/500 terminado. Recompensa: -200.0
# Episode 5/500 terminado. Recompensa: -200.0
# Episode 6/500 terminado. Recompensa: -200.0
# Episode 7/500 terminado. Recompensa: -200.0
# Episode 8/500 terminado. Recompensa: -200.0
# Episode 9/500 terminado. Recompensa: -200.0
# Episode 10/500 terminado. Recompensa: -200.0
# Episode 11/500 terminado. Recompensa: -200.0
# Episode 12/500 terminado. Recompensa: -200.0
# Episode 13/500 terminado. Recompensa: -200.0
# Episode 14/500 terminado. Recompensa: -200.0
# Episode 15/500 terminado. Recompensa: -200.0
# Episode 16/500 terminado. Recompensa: -200.0
# Episode 17/500 terminado. Recompensa: -200.0
# Episode 18/500 terminado. Recompensa: -200.0
# Episode 19/500 terminado. Recompensa: -200.0
# Episode 20/500 terminado. Recompensa: -200.0
# Episode 21/500 terminado. Recompensa: -200.0
# Episode 22/500 terminado. Recompensa: -200.0
# Episode 23/500 terminado. Recompensa: -200.0
# Episode 24/500 terminado. Recompensa: -200.0
# Episode 25/500 terminado. Recompensa: -200.0
# Episode 26/500 terminado. Recompensa: -200.0
# Episode 27/500 terminado. Recompensa: -200.0
# Episode 28/500 terminado. Recompensa: -200.0
# Episode 29/500 terminado. Recompensa: -200.0
# Episode 30/500 terminado. Recompensa: -200.0
# Episode 31/500 terminado. Recompensa: -200.0
# Episode 32/500 terminado. Recompensa: -200.0
# Episode 33/500 terminado. Recompensa: -200.0
# Episode 34/500 terminado. Recompensa: -200.0
# Episode 35/500 terminado. Recompensa: -200.0
# Episode 36/500 terminado. Recompensa: -200.0
# Episode 37/500 terminado. Recompensa: -200.0
# Episode 38/500 terminado. Recompensa: -200.0
# Episode 39/500 terminado. Recompensa: -200.0
# Episode 40/500 terminado. Recompensa: -200.0
# Episode 41/500 terminado. Recompensa: -200.0
# Episode 42/500 terminado. Recompensa: -200.0
# Episode 43/500 terminado. Recompensa: -200.0
# Episode 44/500 terminado. Recompensa: -200.0
# Episode 45/500 terminado. Recompensa: -200.0
# Episode 46/500 terminado. Recompensa: -200.0
# Episode 47/500 terminado. Recompensa: -200.0
# Episode 48/500 terminado. Recompensa: -200.0
# Episode 49/500 terminado. Recompensa: -200.0
# Episode 50/500 terminado. Recompensa: -200.0
# Episode 51/500 terminado. Recompensa: -200.0
# Episode 52/500 terminado. Recompensa: -200.0
# Episode 53/500 terminado. Recompensa: -200.0
# Episode 54/500 terminado. Recompensa: -200.0
# Episode 55/500 terminado. Recompensa: -200.0
# Episode 56/500 terminado. Recompensa: -200.0
# Episode 57/500 terminado. Recompensa: -200.0
# Episode 58/500 terminado. Recompensa: -200.0
# Episode 59/500 terminado. Recompensa: -200.0
# Episode 60/500 terminado. Recompensa: -200.0
# Episode 61/500 terminado. Recompensa: -200.0
# Episode 62/500 terminado. Recompensa: -200.0
# Episode 63/500 terminado. Recompensa: -200.0
# Episode 64/500 terminado. Recompensa: -200.0
# Episode 65/500 terminado. Recompensa: -200.0
# Episode 66/500 terminado. Recompensa: -200.0
# Episode 67/500 terminado. Recompensa: -200.0
# Episode 68/500 terminado. Recompensa: -200.0
# Episode 69/500 terminado. Recompensa: -200.0
# Episode 70/500 terminado. Recompensa: -200.0
# Episode 71/500 terminado. Recompensa: -200.0
# Episode 72/500 terminado. Recompensa: -200.0
# Episode 73/500 terminado. Recompensa: -200.0
# Episode 74/500 terminado. Recompensa: -200.0
# Episode 75/500 terminado. Recompensa: -200.0
# Episode 76/500 terminado. Recompensa: -200.0
# Episode 77/500 terminado. Recompensa: -200.0
# Episode 78/500 terminado. Recompensa: -200.0
# Episode 79/500 terminado. Recompensa: -200.0
# Episode 80/500 terminado. Recompensa: -200.0
# Episode 81/500 terminado. Recompensa: -200.0
# Episode 82/500 terminado. Recompensa: -200.0
# Episode 83/500 terminado. Recompensa: -200.0
# Episode 84/500 terminado. Recompensa: -200.0
# Episode 85/500 terminado. Recompensa: -200.0
# Episode 86/500 terminado. Recompensa: -200.0
# Episode 87/500 terminado. Recompensa: -200.0
# Episode 88/500 terminado. Recompensa: -200.0
# Episode 89/500 terminado. Recompensa: -200.0
# Episode 90/500 terminado. Recompensa: -200.0
# Episode 91/500 terminado. Recompensa: -200.0
# Episode 92/500 terminado. Recompensa: -200.0
# Episode 93/500 terminado. Recompensa: -200.0
# Episode 94/500 terminado. Recompensa: -200.0
# Episode 95/500 terminado. Recompensa: -200.0
# Episode 96/500 terminado. Recompensa: -200.0
# Episode 97/500 terminado. Recompensa: -200.0
# Episode 98/500 terminado. Recompensa: -200.0
# Episode 99/500 terminado. Recompensa: -200.0
# Episode 100/500 terminado. Recompensa: -200.0
# Episode 101/500 terminado. Recompensa: -200.0
# Episode 102/500 terminado. Recompensa: -200.0
# Episode 103/500 terminado. Recompensa: -200.0
# Episode 104/500 terminado. Recompensa: -200.0
# Episode 105/500 terminado. Recompensa: -200.0
# Episode 106/500 terminado. Recompensa: -200.0
# Episode 107/500 terminado. Recompensa: -200.0
# Episode 108/500 terminado. Recompensa: -200.0
# Episode 109/500 terminado. Recompensa: -200.0
# Episode 110/500 terminado. Recompensa: -200.0
# Episode 111/500 terminado. Recompensa: -200.0
# Episode 112/500 terminado. Recompensa: -200.0
# Episode 113/500 terminado. Recompensa: -200.0
# Episode 114/500 terminado. Recompensa: -200.0
# Episode 115/500 terminado. Recompensa: -200.0
# Episode 116/500 terminado. Recompensa: -200.0
# Episode 117/500 terminado. Recompensa: -200.0
# Episode 118/500 terminado. Recompensa: -200.0
# Episode 119/500 terminado. Recompensa: -200.0
# Episode 120/500 terminado. Recompensa: -200.0
# Episode 121/500 terminado. Recompensa: -200.0
# Episode 122/500 terminado. Recompensa: -200.0
# Episode 123/500 terminado. Recompensa: -200.0
# Episode 124/500 terminado. Recompensa: -200.0
# Episode 125/500 terminado. Recompensa: -200.0
# Episode 126/500 terminado. Recompensa: -200.0
# Episode 127/500 terminado. Recompensa: -200.0
# Episode 128/500 terminado. Recompensa: -200.0
# Episode 129/500 terminado. Recompensa: -200.0
# Episode 130/500 terminado. Recompensa: -200.0
# Episode 131/500 terminado. Recompensa: -200.0
# Episode 132/500 terminado. Recompensa: -200.0
# Episode 133/500 terminado. Recompensa: -200.0
# Episode 134/500 terminado. Recompensa: -200.0
# Episode 135/500 terminado. Recompensa: -200.0
# Episode 136/500 terminado. Recompensa: -200.0
# Episode 137/500 terminado. Recompensa: -200.0
# Episode 138/500 terminado. Recompensa: -200.0
# Episode 139/500 terminado. Recompensa: -200.0
# Episode 140/500 terminado. Recompensa: -200.0
# Episode 141/500 terminado. Recompensa: -200.0
# Episode 142/500 terminado. Recompensa: -200.0
# Episode 143/500 terminado. Recompensa: -200.0
# Episode 144/500 terminado. Recompensa: -200.0
# Episode 145/500 terminado. Recompensa: -200.0
# Episode 146/500 terminado. Recompensa: -200.0
# Episode 147/500 terminado. Recompensa: -200.0
# Episode 148/500 terminado. Recompensa: -200.0
# Episode 149/500 terminado. Recompensa: -200.0
# Episode 150/500 terminado. Recompensa: -200.0
# Episode 151/500 terminado. Recompensa: -200.0
# Episode 152/500 terminado. Recompensa: -200.0
# Episode 153/500 terminado. Recompensa: -200.0
# Episode 154/500 terminado. Recompensa: -200.0
# Episode 155/500 terminado. Recompensa: -200.0
# Episode 156/500 terminado. Recompensa: -200.0
# Episode 157/500 terminado. Recompensa: -200.0
# Episode 158/500 terminado. Recompensa: -200.0
# Episode 159/500 terminado. Recompensa: -200.0
# Episode 160/500 terminado. Recompensa: -200.0
# Episode 161/500 terminado. Recompensa: -200.0
# Episode 162/500 terminado. Recompensa: -200.0
# Episode 163/500 terminado. Recompensa: -200.0
# Episode 164/500 terminado. Recompensa: -200.0
# Episode 165/500 terminado. Recompensa: -200.0
# Episode 166/500 terminado. Recompensa: -200.0
# Episode 167/500 terminado. Recompensa: -200.0
# Episode 168/500 terminado. Recompensa: -200.0
# Episode 169/500 terminado. Recompensa: -200.0
# Episode 170/500 terminado. Recompensa: -200.0
# Episode 171/500 terminado. Recompensa: -200.0
# Episode 172/500 terminado. Recompensa: -200.0
# Episode 173/500 terminado. Recompensa: -200.0
# Episode 174/500 terminado. Recompensa: -200.0
# Episode 175/500 terminado. Recompensa: -200.0
# Episode 176/500 terminado. Recompensa: -200.0
# Episode 177/500 terminado. Recompensa: -200.0
# Episode 178/500 terminado. Recompensa: -200.0
# Episode 179/500 terminado. Recompensa: -200.0
# Episode 180/500 terminado. Recompensa: -200.0
# Episode 181/500 terminado. Recompensa: -200.0
# Episode 182/500 terminado. Recompensa: -200.0
# Episode 183/500 terminado. Recompensa: -200.0
# Episode 184/500 terminado. Recompensa: -200.0
# Episode 185/500 terminado. Recompensa: -200.0
# Episode 186/500 terminado. Recompensa: -200.0
# Episode 187/500 terminado. Recompensa: -200.0
# Episode 188/500 terminado. Recompensa: -200.0
# Episode 189/500 terminado. Recompensa: -200.0
# Episode 190/500 terminado. Recompensa: -200.0
# Episode 191/500 terminado. Recompensa: -200.0
# Episode 192/500 terminado. Recompensa: -200.0
# Episode 193/500 terminado. Recompensa: -200.0
# Episode 194/500 terminado. Recompensa: -200.0
# Episode 195/500 terminado. Recompensa: -200.0
# Episode 196/500 terminado. Recompensa: -200.0
# Episode 197/500 terminado. Recompensa: -200.0
# Episode 198/500 terminado. Recompensa: -200.0
# Episode 199/500 terminado. Recompensa: -200.0
# Episode 200/500 terminado. Recompensa: -200.0
# Episode 201/500 terminado. Recompensa: -200.0
# Episode 202/500 terminado. Recompensa: -200.0
# Episode 203/500 terminado. Recompensa: -200.0
# Episode 204/500 terminado. Recompensa: -200.0
# Episode 205/500 terminado. Recompensa: -200.0
# Episode 206/500 terminado. Recompensa: -200.0
# Episode 207/500 terminado. Recompensa: -200.0
# Episode 208/500 terminado. Recompensa: -200.0
# Episode 209/500 terminado. Recompensa: -200.0
# Episode 210/500 terminado. Recompensa: -200.0
# Episode 211/500 terminado. Recompensa: -200.0
# Episode 212/500 terminado. Recompensa: -200.0
# Episode 213/500 terminado. Recompensa: -200.0
# Episode 214/500 terminado. Recompensa: -200.0
# Episode 215/500 terminado. Recompensa: -200.0
# Episode 216/500 terminado. Recompensa: -200.0
# Episode 217/500 terminado. Recompensa: -200.0
# Episode 218/500 terminado. Recompensa: -200.0
# Episode 219/500 terminado. Recompensa: -200.0
# Episode 220/500 terminado. Recompensa: -200.0
# Episode 221/500 terminado. Recompensa: -200.0
# Episode 222/500 terminado. Recompensa: -200.0
# Episode 223/500 terminado. Recompensa: -200.0
# Episode 224/500 terminado. Recompensa: -200.0
# Episode 225/500 terminado. Recompensa: -200.0
# Episode 226/500 terminado. Recompensa: -200.0
# Episode 227/500 terminado. Recompensa: -200.0
# Episode 228/500 terminado. Recompensa: -200.0
# Episode 229/500 terminado. Recompensa: -200.0
# Episode 230/500 terminado. Recompensa: -200.0
# Episode 231/500 terminado. Recompensa: -200.0
# Episode 232/500 terminado. Recompensa: -200.0
# Episode 233/500 terminado. Recompensa: -200.0
# Episode 234/500 terminado. Recompensa: -200.0
# Episode 235/500 terminado. Recompensa: -200.0
# Episode 236/500 terminado. Recompensa: -200.0
# Episode 237/500 terminado. Recompensa: -200.0
# Episode 238/500 terminado. Recompensa: -200.0
# Episode 239/500 terminado. Recompensa: -200.0
# Episode 240/500 terminado. Recompensa: -200.0
# Episode 241/500 terminado. Recompensa: -200.0
# Episode 242/500 terminado. Recompensa: -200.0
# Episode 243/500 terminado. Recompensa: -200.0
# Episode 244/500 terminado. Recompensa: -200.0
# Episode 245/500 terminado. Recompensa: -200.0
# Episode 246/500 terminado. Recompensa: -200.0
# Episode 247/500 terminado. Recompensa: -200.0
# Episode 248/500 terminado. Recompensa: -200.0
# Episode 249/500 terminado. Recompensa: -200.0
# Episode 250/500 terminado. Recompensa: -200.0
# Episode 251/500 terminado. Recompensa: -200.0
# Episode 252/500 terminado. Recompensa: -200.0
# Episode 253/500 terminado. Recompensa: -200.0
# Episode 254/500 terminado. Recompensa: -200.0
# Episode 255/500 terminado. Recompensa: -200.0
# Episode 256/500 terminado. Recompensa: -200.0
# Episode 257/500 terminado. Recompensa: -200.0
# Episode 258/500 terminado. Recompensa: -200.0
# Episode 259/500 terminado. Recompensa: -200.0
# Episode 260/500 terminado. Recompensa: -200.0
# Episode 261/500 terminado. Recompensa: -200.0
# Episode 262/500 terminado. Recompensa: -200.0
# Episode 263/500 terminado. Recompensa: -200.0
# Episode 264/500 terminado. Recompensa: -200.0
# Episode 265/500 terminado. Recompensa: -200.0
# Episode 266/500 terminado. Recompensa: -200.0
# Episode 267/500 terminado. Recompensa: -200.0
# Episode 268/500 terminado. Recompensa: -200.0
# Episode 269/500 terminado. Recompensa: -200.0
# Episode 270/500 terminado. Recompensa: -200.0
# Episode 271/500 terminado. Recompensa: -200.0
# Episode 272/500 terminado. Recompensa: -200.0
# Episode 273/500 terminado. Recompensa: -200.0
# Episode 274/500 terminado. Recompensa: -200.0
# Episode 275/500 terminado. Recompensa: -200.0
# Episode 276/500 terminado. Recompensa: -200.0
# Episode 277/500 terminado. Recompensa: -200.0
# Episode 278/500 terminado. Recompensa: -200.0
# Episode 279/500 terminado. Recompensa: -200.0
# Episode 280/500 terminado. Recompensa: -200.0
# Episode 281/500 terminado. Recompensa: -200.0
# Episode 282/500 terminado. Recompensa: -200.0
# Episode 283/500 terminado. Recompensa: -200.0
# Episode 284/500 terminado. Recompensa: -200.0
# Episode 285/500 terminado. Recompensa: -200.0
# Episode 286/500 terminado. Recompensa: -200.0
# Episode 287/500 terminado. Recompensa: -200.0
# Episode 288/500 terminado. Recompensa: -200.0
# Episode 289/500 terminado. Recompensa: -200.0
# Episode 290/500 terminado. Recompensa: -200.0
# Episode 291/500 terminado. Recompensa: -200.0
# Episode 292/500 terminado. Recompensa: -200.0
# Episode 293/500 terminado. Recompensa: -200.0
# Episode 294/500 terminado. Recompensa: -200.0
# Episode 295/500 terminado. Recompensa: -200.0
# Episode 296/500 terminado. Recompensa: -200.0
# Episode 297/500 terminado. Recompensa: -200.0
# Episode 298/500 terminado. Recompensa: -200.0
# Episode 299/500 terminado. Recompensa: -200.0
# Episode 300/500 terminado. Recompensa: -200.0
# Episode 301/500 terminado. Recompensa: -200.0
# Episode 302/500 terminado. Recompensa: -200.0
# Episode 303/500 terminado. Recompensa: -200.0
# Episode 304/500 terminado. Recompensa: -200.0
# Episode 305/500 terminado. Recompensa: -200.0
# Episode 306/500 terminado. Recompensa: -200.0
# Episode 307/500 terminado. Recompensa: -200.0
# Episode 308/500 terminado. Recompensa: -200.0
# Episode 309/500 terminado. Recompensa: -200.0
# Episode 310/500 terminado. Recompensa: -200.0
# Episode 311/500 terminado. Recompensa: -200.0
# Episode 312/500 terminado. Recompensa: -200.0
# Episode 313/500 terminado. Recompensa: -200.0
# Episode 314/500 terminado. Recompensa: -200.0
# Episode 315/500 terminado. Recompensa: -200.0
# Episode 316/500 terminado. Recompensa: -200.0
# Episode 317/500 terminado. Recompensa: -200.0
# Episode 318/500 terminado. Recompensa: -200.0
# Episode 319/500 terminado. Recompensa: -200.0
# Episode 320/500 terminado. Recompensa: -200.0
# Episode 321/500 terminado. Recompensa: -200.0
# Episode 322/500 terminado. Recompensa: -200.0
# Episode 323/500 terminado. Recompensa: -200.0
# Episode 324/500 terminado. Recompensa: -200.0
# Episode 325/500 terminado. Recompensa: -200.0
# Episode 326/500 terminado. Recompensa: -200.0
# Episode 327/500 terminado. Recompensa: -200.0
# Episode 328/500 terminado. Recompensa: -200.0
# Episode 329/500 terminado. Recompensa: -200.0
# Episode 330/500 terminado. Recompensa: -200.0
# Episode 331/500 terminado. Recompensa: -200.0
# Episode 332/500 terminado. Recompensa: -200.0
# Episode 333/500 terminado. Recompensa: -200.0
# Episode 334/500 terminado. Recompensa: -200.0
# Episode 335/500 terminado. Recompensa: -200.0
# Episode 336/500 terminado. Recompensa: -200.0
# Episode 337/500 terminado. Recompensa: -200.0
# Episode 338/500 terminado. Recompensa: -200.0
# Episode 339/500 terminado. Recompensa: -200.0
# Episode 340/500 terminado. Recompensa: -200.0
# Episode 341/500 terminado. Recompensa: -200.0
# Episode 342/500 terminado. Recompensa: -200.0
# Episode 343/500 terminado. Recompensa: -200.0
# Episode 344/500 terminado. Recompensa: -200.0
# Episode 345/500 terminado. Recompensa: -200.0
# Episode 346/500 terminado. Recompensa: -200.0
# Episode 347/500 terminado. Recompensa: -200.0
# Episode 348/500 terminado. Recompensa: -200.0
# Episode 349/500 terminado. Recompensa: -200.0
# Episode 350/500 terminado. Recompensa: -200.0
# Episode 351/500 terminado. Recompensa: -200.0
# Episode 352/500 terminado. Recompensa: -200.0
# Episode 353/500 terminado. Recompensa: -200.0
# Episode 354/500 terminado. Recompensa: -200.0
# Episode 355/500 terminado. Recompensa: -200.0
# Episode 356/500 terminado. Recompensa: -200.0
# Episode 357/500 terminado. Recompensa: -200.0
# Episode 358/500 terminado. Recompensa: -200.0
# Episode 359/500 terminado. Recompensa: -200.0
# Episode 360/500 terminado. Recompensa: -200.0
# Episode 361/500 terminado. Recompensa: -200.0
# Episode 362/500 terminado. Recompensa: -200.0
# Episode 363/500 terminado. Recompensa: -200.0
# Episode 364/500 terminado. Recompensa: -200.0
# Episode 365/500 terminado. Recompensa: -200.0
# Episode 366/500 terminado. Recompensa: -200.0
# Episode 367/500 terminado. Recompensa: -200.0
# Episode 368/500 terminado. Recompensa: -200.0
# Episode 369/500 terminado. Recompensa: -200.0
# Episode 370/500 terminado. Recompensa: -200.0
# Episode 371/500 terminado. Recompensa: -200.0
# Episode 372/500 terminado. Recompensa: -200.0
# Episode 373/500 terminado. Recompensa: -200.0
# Episode 374/500 terminado. Recompensa: -200.0
# Episode 375/500 terminado. Recompensa: -200.0
# Episode 376/500 terminado. Recompensa: -200.0
# Episode 377/500 terminado. Recompensa: -200.0
# Episode 378/500 terminado. Recompensa: -200.0
# Episode 379/500 terminado. Recompensa: -200.0
# Episode 380/500 terminado. Recompensa: -200.0
# Episode 381/500 terminado. Recompensa: -200.0
# Episode 382/500 terminado. Recompensa: -200.0
# Episode 383/500 terminado. Recompensa: -200.0
# Episode 384/500 terminado. Recompensa: -200.0
# Episode 385/500 terminado. Recompensa: -200.0
# Episode 386/500 terminado. Recompensa: -200.0
# Episode 387/500 terminado. Recompensa: -200.0
# Episode 388/500 terminado. Recompensa: -200.0
# Episode 389/500 terminado. Recompensa: -200.0
# Episode 390/500 terminado. Recompensa: -200.0
# Episode 391/500 terminado. Recompensa: -200.0
# Episode 392/500 terminado. Recompensa: -200.0
# Episode 393/500 terminado. Recompensa: -200.0
# Episode 394/500 terminado. Recompensa: -200.0
# Episode 395/500 terminado. Recompensa: -200.0
# Episode 396/500 terminado. Recompensa: -200.0
# Episode 397/500 terminado. Recompensa: -200.0
# Episode 398/500 terminado. Recompensa: -200.0
# Episode 399/500 terminado. Recompensa: -200.0
# Episode 400/500 terminado. Recompensa: -200.0
# Episode 401/500 terminado. Recompensa: -200.0
# Episode 402/500 terminado. Recompensa: -200.0
# Episode 403/500 terminado. Recompensa: -200.0
# Episode 404/500 terminado. Recompensa: -200.0
# Episode 405/500 terminado. Recompensa: -200.0
# Episode 406/500 terminado. Recompensa: -200.0
# Episode 407/500 terminado. Recompensa: -200.0
# Episode 408/500 terminado. Recompensa: -200.0
# Episode 409/500 terminado. Recompensa: -200.0
# Episode 410/500 terminado. Recompensa: -200.0
# Episode 411/500 terminado. Recompensa: -200.0
# Episode 412/500 terminado. Recompensa: -200.0
# Episode 413/500 terminado. Recompensa: -200.0
# Episode 414/500 terminado. Recompensa: -200.0
# Episode 415/500 terminado. Recompensa: -200.0
# Episode 416/500 terminado. Recompensa: -200.0
# Episode 417/500 terminado. Recompensa: -200.0
# Episode 418/500 terminado. Recompensa: -200.0
# Episode 419/500 terminado. Recompensa: -200.0
# Episode 420/500 terminado. Recompensa: -200.0
# Episode 421/500 terminado. Recompensa: -200.0
# Episode 422/500 terminado. Recompensa: -200.0
# Episode 423/500 terminado. Recompensa: -200.0
# Episode 424/500 terminado. Recompensa: -200.0
# Episode 425/500 terminado. Recompensa: -200.0
# Episode 426/500 terminado. Recompensa: -200.0
# Episode 427/500 terminado. Recompensa: -200.0
# Episode 428/500 terminado. Recompensa: -200.0
# Episode 429/500 terminado. Recompensa: -200.0
# Episode 430/500 terminado. Recompensa: -200.0
# Episode 431/500 terminado. Recompensa: -200.0
# Episode 432/500 terminado. Recompensa: -200.0
# Episode 433/500 terminado. Recompensa: -200.0
# Episode 434/500 terminado. Recompensa: -200.0
# Episode 435/500 terminado. Recompensa: -200.0
# Episode 436/500 terminado. Recompensa: -200.0
# Episode 437/500 terminado. Recompensa: -200.0
# Episode 438/500 terminado. Recompensa: -200.0
# Episode 439/500 terminado. Recompensa: -200.0
# Episode 440/500 terminado. Recompensa: -200.0
# Episode 441/500 terminado. Recompensa: -200.0
# Episode 442/500 terminado. Recompensa: -200.0
# Episode 443/500 terminado. Recompensa: -200.0
# Episode 444/500 terminado. Recompensa: -200.0
# Episode 445/500 terminado. Recompensa: -200.0
# Episode 446/500 terminado. Recompensa: -200.0
# Episode 447/500 terminado. Recompensa: -200.0
# Episode 448/500 terminado. Recompensa: -200.0
# Episode 449/500 terminado. Recompensa: -200.0
# Episode 450/500 terminado. Recompensa: -200.0
# Episode 451/500 terminado. Recompensa: -200.0
# Episode 452/500 terminado. Recompensa: -200.0
# Episode 453/500 terminado. Recompensa: -200.0
# Episode 454/500 terminado. Recompensa: -200.0
# Episode 455/500 terminado. Recompensa: -200.0
# Episode 456/500 terminado. Recompensa: -200.0
# Episode 457/500 terminado. Recompensa: -200.0
# Episode 458/500 terminado. Recompensa: -200.0
# Episode 459/500 terminado. Recompensa: -200.0
# Episode 460/500 terminado. Recompensa: -200.0
# Episode 461/500 terminado. Recompensa: -200.0
# Episode 462/500 terminado. Recompensa: -200.0
# Episode 463/500 terminado. Recompensa: -200.0
# Episode 464/500 terminado. Recompensa: -200.0
# Episode 465/500 terminado. Recompensa: -200.0
# Episode 466/500 terminado. Recompensa: -200.0
# Episode 467/500 terminado. Recompensa: -200.0
# Episode 468/500 terminado. Recompensa: -200.0
# Episode 469/500 terminado. Recompensa: -200.0
# Episode 470/500 terminado. Recompensa: -200.0
# Episode 471/500 terminado. Recompensa: -200.0
# Episode 472/500 terminado. Recompensa: -200.0
# Episode 473/500 terminado. Recompensa: -200.0
# Episode 474/500 terminado. Recompensa: -200.0
# Episode 475/500 terminado. Recompensa: -200.0
# Episode 476/500 terminado. Recompensa: -200.0
# Episode 477/500 terminado. Recompensa: -200.0
# Episode 478/500 terminado. Recompensa: -200.0
# Episode 479/500 terminado. Recompensa: -200.0
# Episode 480/500 terminado. Recompensa: -200.0
# Episode 481/500 terminado. Recompensa: -200.0
# Episode 482/500 terminado. Recompensa: -200.0
# Episode 483/500 terminado. Recompensa: -200.0
# Episode 484/500 terminado. Recompensa: -200.0
# Episode 485/500 terminado. Recompensa: -200.0
# Episode 486/500 terminado. Recompensa: -200.0
# Episode 487/500 terminado. Recompensa: -200.0
# Episode 488/500 terminado. Recompensa: -200.0
# Episode 489/500 terminado. Recompensa: -200.0
# Episode 490/500 terminado. Recompensa: -200.0
# Episode 491/500 terminado. Recompensa: -200.0
# Episode 492/500 terminado. Recompensa: -200.0
# Episode 493/500 terminado. Recompensa: -200.0
# Episode 494/500 terminado. Recompensa: -200.0
# Episode 495/500 terminado. Recompensa: -200.0
# Episode 496/500 terminado. Recompensa: -200.0
# Episode 497/500 terminado. Recompensa: -200.0
# Episode 498/500 terminado. Recompensa: -200.0
# Episode 499/500 terminado. Recompensa: -200.0
# Episode 500/500 terminado. Recompensa: -200.0
#
# === Experimento 2 ===
# Episode 1/500 terminado. Recompensa: -200.0
# Episode 2/500 terminado. Recompensa: -200.0
# Episode 3/500 terminado. Recompensa: -200.0
# Episode 4/500 terminado. Recompensa: -200.0
# Episode 5/500 terminado. Recompensa: -200.0
# Episode 6/500 terminado. Recompensa: -200.0
# Episode 7/500 terminado. Recompensa: -200.0
# Episode 8/500 terminado. Recompensa: -200.0
# Episode 9/500 terminado. Recompensa: -200.0
# Episode 10/500 terminado. Recompensa: -200.0
# Episode 11/500 terminado. Recompensa: -200.0
# Episode 12/500 terminado. Recompensa: -200.0
# Episode 13/500 terminado. Recompensa: -200.0
# Episode 14/500 terminado. Recompensa: -200.0
# Episode 15/500 terminado. Recompensa: -200.0
# Episode 16/500 terminado. Recompensa: -200.0
# Episode 17/500 terminado. Recompensa: -200.0
# Episode 18/500 terminado. Recompensa: -200.0
# Episode 19/500 terminado. Recompensa: -200.0
# Episode 20/500 terminado. Recompensa: -200.0
# Episode 21/500 terminado. Recompensa: -200.0
# Episode 22/500 terminado. Recompensa: -200.0
# Episode 23/500 terminado. Recompensa: -200.0
# Episode 24/500 terminado. Recompensa: -200.0
# Episode 25/500 terminado. Recompensa: -200.0
# Episode 26/500 terminado. Recompensa: -200.0
# Episode 27/500 terminado. Recompensa: -200.0
# Episode 28/500 terminado. Recompensa: -200.0
# Episode 29/500 terminado. Recompensa: -200.0
# Episode 30/500 terminado. Recompensa: -200.0
# Episode 31/500 terminado. Recompensa: -200.0
# Episode 32/500 terminado. Recompensa: -200.0
# Episode 33/500 terminado. Recompensa: -200.0
# Episode 34/500 terminado. Recompensa: -200.0
# Episode 35/500 terminado. Recompensa: -200.0
# Episode 36/500 terminado. Recompensa: -200.0
# Episode 37/500 terminado. Recompensa: -200.0
# Episode 38/500 terminado. Recompensa: -200.0
# Episode 39/500 terminado. Recompensa: -200.0
# Episode 40/500 terminado. Recompensa: -200.0
# Episode 41/500 terminado. Recompensa: -200.0
# Episode 42/500 terminado. Recompensa: -200.0
# Episode 43/500 terminado. Recompensa: -200.0
# Episode 44/500 terminado. Recompensa: -200.0
# Episode 45/500 terminado. Recompensa: -200.0
# Episode 46/500 terminado. Recompensa: -200.0
# Episode 47/500 terminado. Recompensa: -200.0
# Episode 48/500 terminado. Recompensa: -200.0
# Episode 49/500 terminado. Recompensa: -200.0
# Episode 50/500 terminado. Recompensa: -200.0
# Episode 51/500 terminado. Recompensa: -200.0
# Episode 52/500 terminado. Recompensa: -200.0
# Episode 53/500 terminado. Recompensa: -200.0
# Episode 54/500 terminado. Recompensa: -200.0
# Episode 55/500 terminado. Recompensa: -200.0
# Episode 56/500 terminado. Recompensa: -200.0
# Episode 57/500 terminado. Recompensa: -200.0
# Episode 58/500 terminado. Recompensa: -200.0
# Episode 59/500 terminado. Recompensa: -200.0
# Episode 60/500 terminado. Recompensa: -200.0
# Episode 61/500 terminado. Recompensa: -200.0
# Episode 62/500 terminado. Recompensa: -200.0
# Episode 63/500 terminado. Recompensa: -200.0
# Episode 64/500 terminado. Recompensa: -200.0
# Episode 65/500 terminado. Recompensa: -200.0
# Episode 66/500 terminado. Recompensa: -200.0
# Episode 67/500 terminado. Recompensa: -200.0
# Episode 68/500 terminado. Recompensa: -200.0
# Episode 69/500 terminado. Recompensa: -200.0
# Episode 70/500 terminado. Recompensa: -200.0
# Episode 71/500 terminado. Recompensa: -200.0
# Episode 72/500 terminado. Recompensa: -200.0
# Episode 73/500 terminado. Recompensa: -200.0
# Episode 74/500 terminado. Recompensa: -200.0
# Episode 75/500 terminado. Recompensa: -200.0
# Episode 76/500 terminado. Recompensa: -200.0
# Episode 77/500 terminado. Recompensa: -200.0
# Episode 78/500 terminado. Recompensa: -200.0
# Episode 79/500 terminado. Recompensa: -200.0
# Episode 80/500 terminado. Recompensa: -200.0
# Episode 81/500 terminado. Recompensa: -200.0
# Episode 82/500 terminado. Recompensa: -200.0
# Episode 83/500 terminado. Recompensa: -200.0
# Episode 84/500 terminado. Recompensa: -200.0
# Episode 85/500 terminado. Recompensa: -200.0
# Episode 86/500 terminado. Recompensa: -200.0
# Episode 87/500 terminado. Recompensa: -200.0
# Episode 88/500 terminado. Recompensa: -200.0
# Episode 89/500 terminado. Recompensa: -200.0
# Episode 90/500 terminado. Recompensa: -200.0
# Episode 91/500 terminado. Recompensa: -200.0
# Episode 92/500 terminado. Recompensa: -200.0
# Episode 93/500 terminado. Recompensa: -200.0
# Episode 94/500 terminado. Recompensa: -200.0
# Episode 95/500 terminado. Recompensa: -200.0
# Episode 96/500 terminado. Recompensa: -200.0
# Episode 97/500 terminado. Recompensa: -200.0
# Episode 98/500 terminado. Recompensa: -200.0
# Episode 99/500 terminado. Recompensa: -200.0
# Episode 100/500 terminado. Recompensa: -200.0
# Episode 101/500 terminado. Recompensa: -200.0
# Episode 102/500 terminado. Recompensa: -200.0
# Episode 103/500 terminado. Recompensa: -200.0
# Episode 104/500 terminado. Recompensa: -200.0
# Episode 105/500 terminado. Recompensa: -200.0
# Episode 106/500 terminado. Recompensa: -200.0
# Episode 107/500 terminado. Recompensa: -200.0
# Episode 108/500 terminado. Recompensa: -200.0
# Episode 109/500 terminado. Recompensa: -200.0
# Episode 110/500 terminado. Recompensa: -200.0
# Episode 111/500 terminado. Recompensa: -200.0
# Episode 112/500 terminado. Recompensa: -200.0
# Episode 113/500 terminado. Recompensa: -200.0
# Episode 114/500 terminado. Recompensa: -200.0
# Episode 115/500 terminado. Recompensa: -200.0
# Episode 116/500 terminado. Recompensa: -200.0
# Episode 117/500 terminado. Recompensa: -200.0
# Episode 118/500 terminado. Recompensa: -200.0
# Episode 119/500 terminado. Recompensa: -200.0
# Episode 120/500 terminado. Recompensa: -200.0
# Episode 121/500 terminado. Recompensa: -200.0
# Episode 122/500 terminado. Recompensa: -200.0
# Episode 123/500 terminado. Recompensa: -200.0
# Episode 124/500 terminado. Recompensa: -200.0
# Episode 125/500 terminado. Recompensa: -200.0
# Episode 126/500 terminado. Recompensa: -200.0
# Episode 127/500 terminado. Recompensa: -200.0
# Episode 128/500 terminado. Recompensa: -200.0
# Episode 129/500 terminado. Recompensa: -200.0
# Episode 130/500 terminado. Recompensa: -200.0
# Episode 131/500 terminado. Recompensa: -200.0
# Episode 132/500 terminado. Recompensa: -200.0
# Episode 133/500 terminado. Recompensa: -200.0
# Episode 134/500 terminado. Recompensa: -200.0
# Episode 135/500 terminado. Recompensa: -200.0
# Episode 136/500 terminado. Recompensa: -200.0
# Episode 137/500 terminado. Recompensa: -200.0
# Episode 138/500 terminado. Recompensa: -200.0
# Episode 139/500 terminado. Recompensa: -200.0
# Episode 140/500 terminado. Recompensa: -200.0
# Episode 141/500 terminado. Recompensa: -200.0
# Episode 142/500 terminado. Recompensa: -200.0
# Episode 143/500 terminado. Recompensa: -200.0
# Episode 144/500 terminado. Recompensa: -200.0
# Episode 145/500 terminado. Recompensa: -200.0
# Episode 146/500 terminado. Recompensa: -200.0
# Episode 147/500 terminado. Recompensa: -200.0
# Episode 148/500 terminado. Recompensa: -200.0
# Episode 149/500 terminado. Recompensa: -200.0
# Episode 150/500 terminado. Recompensa: -200.0
# Episode 151/500 terminado. Recompensa: -200.0
# Episode 152/500 terminado. Recompensa: -200.0
# Episode 153/500 terminado. Recompensa: -200.0
# Episode 154/500 terminado. Recompensa: -200.0
# Episode 155/500 terminado. Recompensa: -200.0
# Episode 156/500 terminado. Recompensa: -200.0
# Episode 157/500 terminado. Recompensa: -200.0
# Episode 158/500 terminado. Recompensa: -200.0
# Episode 159/500 terminado. Recompensa: -200.0
# Episode 160/500 terminado. Recompensa: -200.0
# Episode 161/500 terminado. Recompensa: -200.0
# Episode 162/500 terminado. Recompensa: -200.0
# Episode 163/500 terminado. Recompensa: -200.0
# Episode 164/500 terminado. Recompensa: -200.0
# Episode 165/500 terminado. Recompensa: -200.0
# Episode 166/500 terminado. Recompensa: -200.0
# Episode 167/500 terminado. Recompensa: -200.0
# Episode 168/500 terminado. Recompensa: -200.0
# Episode 169/500 terminado. Recompensa: -200.0
# Episode 170/500 terminado. Recompensa: -200.0
# Episode 171/500 terminado. Recompensa: -200.0
# Episode 172/500 terminado. Recompensa: -200.0
# Episode 173/500 terminado. Recompensa: -200.0
# Episode 174/500 terminado. Recompensa: -200.0
# Episode 175/500 terminado. Recompensa: -200.0
# Episode 176/500 terminado. Recompensa: -200.0
# Episode 177/500 terminado. Recompensa: -200.0
# Episode 178/500 terminado. Recompensa: -200.0
# Episode 179/500 terminado. Recompensa: -200.0
# Episode 180/500 terminado. Recompensa: -200.0
# Episode 181/500 terminado. Recompensa: -200.0
# Episode 182/500 terminado. Recompensa: -200.0
# Episode 183/500 terminado. Recompensa: -200.0
# Episode 184/500 terminado. Recompensa: -200.0
# Episode 185/500 terminado. Recompensa: -200.0
# Episode 186/500 terminado. Recompensa: -200.0
# Episode 187/500 terminado. Recompensa: -200.0
# Episode 188/500 terminado. Recompensa: -200.0
# Episode 189/500 terminado. Recompensa: -200.0
# Episode 190/500 terminado. Recompensa: -200.0
# Episode 191/500 terminado. Recompensa: -200.0
# Episode 192/500 terminado. Recompensa: -200.0
# Episode 193/500 terminado. Recompensa: -200.0
# Episode 194/500 terminado. Recompensa: -200.0
# Episode 195/500 terminado. Recompensa: -200.0
# Episode 196/500 terminado. Recompensa: -200.0
# Episode 197/500 terminado. Recompensa: -200.0
# Episode 198/500 terminado. Recompensa: -200.0
# Episode 199/500 terminado. Recompensa: -200.0
# Episode 200/500 terminado. Recompensa: -200.0
# Episode 201/500 terminado. Recompensa: -200.0
# Episode 202/500 terminado. Recompensa: -200.0
# Episode 203/500 terminado. Recompensa: -200.0
# Episode 204/500 terminado. Recompensa: -200.0
# Episode 205/500 terminado. Recompensa: -200.0
# Episode 206/500 terminado. Recompensa: -200.0
# Episode 207/500 terminado. Recompensa: -200.0
# Episode 208/500 terminado. Recompensa: -200.0
# Episode 209/500 terminado. Recompensa: -200.0
# Episode 210/500 terminado. Recompensa: -200.0
# Episode 211/500 terminado. Recompensa: -200.0
# Episode 212/500 terminado. Recompensa: -200.0
# Episode 213/500 terminado. Recompensa: -200.0
# Episode 214/500 terminado. Recompensa: -200.0
# Episode 215/500 terminado. Recompensa: -200.0
# Episode 216/500 terminado. Recompensa: -200.0
# Episode 217/500 terminado. Recompensa: -200.0
# Episode 218/500 terminado. Recompensa: -200.0
# Episode 219/500 terminado. Recompensa: -200.0
# Episode 220/500 terminado. Recompensa: -200.0
# Episode 221/500 terminado. Recompensa: -200.0
# Episode 222/500 terminado. Recompensa: -200.0
# Episode 223/500 terminado. Recompensa: -200.0
# Episode 224/500 terminado. Recompensa: -200.0
# Episode 225/500 terminado. Recompensa: -200.0
# Episode 226/500 terminado. Recompensa: -200.0
# Episode 227/500 terminado. Recompensa: -200.0
# Episode 228/500 terminado. Recompensa: -200.0
# Episode 229/500 terminado. Recompensa: -200.0
# Episode 230/500 terminado. Recompensa: -200.0
# Episode 231/500 terminado. Recompensa: -200.0
# Episode 232/500 terminado. Recompensa: -200.0
# Episode 233/500 terminado. Recompensa: -200.0
# Episode 234/500 terminado. Recompensa: -200.0
# Episode 235/500 terminado. Recompensa: -200.0
# Episode 236/500 terminado. Recompensa: -200.0
# Episode 237/500 terminado. Recompensa: -200.0
# Episode 238/500 terminado. Recompensa: -200.0
# Episode 239/500 terminado. Recompensa: -200.0
# Episode 240/500 terminado. Recompensa: -200.0
# Episode 241/500 terminado. Recompensa: -200.0
# Episode 242/500 terminado. Recompensa: -200.0
# Episode 243/500 terminado. Recompensa: -200.0
# Episode 244/500 terminado. Recompensa: -200.0
# Episode 245/500 terminado. Recompensa: -200.0
# Episode 246/500 terminado. Recompensa: -200.0
# Episode 247/500 terminado. Recompensa: -200.0
# Episode 248/500 terminado. Recompensa: -200.0
# Episode 249/500 terminado. Recompensa: -200.0
# Episode 250/500 terminado. Recompensa: -200.0
# Episode 251/500 terminado. Recompensa: -200.0
# Episode 252/500 terminado. Recompensa: -200.0
# Episode 253/500 terminado. Recompensa: -200.0
# Episode 254/500 terminado. Recompensa: -200.0
# Episode 255/500 terminado. Recompensa: -200.0
# Episode 256/500 terminado. Recompensa: -200.0
# Episode 257/500 terminado. Recompensa: -200.0
# Episode 258/500 terminado. Recompensa: -200.0
# Episode 259/500 terminado. Recompensa: -200.0
# Episode 260/500 terminado. Recompensa: -200.0
# Episode 261/500 terminado. Recompensa: -200.0
# Episode 262/500 terminado. Recompensa: -200.0
# Episode 263/500 terminado. Recompensa: -200.0
# Episode 264/500 terminado. Recompensa: -200.0
# Episode 265/500 terminado. Recompensa: -200.0
# Episode 266/500 terminado. Recompensa: -200.0
# Episode 267/500 terminado. Recompensa: -200.0
# Episode 268/500 terminado. Recompensa: -200.0
# Episode 269/500 terminado. Recompensa: -200.0
# Episode 270/500 terminado. Recompensa: -200.0
# Episode 271/500 terminado. Recompensa: -200.0
# Episode 272/500 terminado. Recompensa: -200.0
# Episode 273/500 terminado. Recompensa: -200.0
# Episode 274/500 terminado. Recompensa: -200.0
# Episode 275/500 terminado. Recompensa: -200.0
# Episode 276/500 terminado. Recompensa: -200.0
# Episode 277/500 terminado. Recompensa: -200.0
# Episode 278/500 terminado. Recompensa: -200.0
# Episode 279/500 terminado. Recompensa: -200.0
# Episode 280/500 terminado. Recompensa: -200.0
# Episode 281/500 terminado. Recompensa: -200.0
# Episode 282/500 terminado. Recompensa: -200.0
# Episode 283/500 terminado. Recompensa: -200.0
# Episode 284/500 terminado. Recompensa: -200.0
# Episode 285/500 terminado. Recompensa: -200.0
# Episode 286/500 terminado. Recompensa: -200.0
# Episode 287/500 terminado. Recompensa: -200.0
# Episode 288/500 terminado. Recompensa: -200.0
# Episode 289/500 terminado. Recompensa: -200.0
# Episode 290/500 terminado. Recompensa: -200.0
# Episode 291/500 terminado. Recompensa: -200.0
# Episode 292/500 terminado. Recompensa: -200.0
# Episode 293/500 terminado. Recompensa: -200.0
# Episode 294/500 terminado. Recompensa: -200.0
# Episode 295/500 terminado. Recompensa: -200.0
# Episode 296/500 terminado. Recompensa: -200.0
# Episode 297/500 terminado. Recompensa: -200.0
# Episode 298/500 terminado. Recompensa: -200.0
# Episode 299/500 terminado. Recompensa: -200.0
# Episode 300/500 terminado. Recompensa: -200.0
# Episode 301/500 terminado. Recompensa: -200.0
# Episode 302/500 terminado. Recompensa: -200.0
# Episode 303/500 terminado. Recompensa: -200.0
# Episode 304/500 terminado. Recompensa: -200.0
# Episode 305/500 terminado. Recompensa: -200.0
# Episode 306/500 terminado. Recompensa: -200.0
# Episode 307/500 terminado. Recompensa: -200.0
# Episode 308/500 terminado. Recompensa: -200.0
# Episode 309/500 terminado. Recompensa: -200.0
# Episode 310/500 terminado. Recompensa: -200.0
# Episode 311/500 terminado. Recompensa: -200.0
# Episode 312/500 terminado. Recompensa: -200.0
# Episode 313/500 terminado. Recompensa: -200.0
# Episode 314/500 terminado. Recompensa: -200.0
# Episode 315/500 terminado. Recompensa: -200.0
# Episode 316/500 terminado. Recompensa: -200.0
# Episode 317/500 terminado. Recompensa: -200.0
# Episode 318/500 terminado. Recompensa: -200.0
# Episode 319/500 terminado. Recompensa: -200.0
# Episode 320/500 terminado. Recompensa: -200.0
# Episode 321/500 terminado. Recompensa: -200.0
# Episode 322/500 terminado. Recompensa: -200.0
# Episode 323/500 terminado. Recompensa: -200.0
# Episode 324/500 terminado. Recompensa: -200.0
# Episode 325/500 terminado. Recompensa: -200.0
# Episode 326/500 terminado. Recompensa: -200.0
# Episode 327/500 terminado. Recompensa: -200.0
# Episode 328/500 terminado. Recompensa: -200.0
# Episode 329/500 terminado. Recompensa: -200.0
# Episode 330/500 terminado. Recompensa: -200.0
# Episode 331/500 terminado. Recompensa: -200.0
# Episode 332/500 terminado. Recompensa: -200.0
# Episode 333/500 terminado. Recompensa: -200.0
# Episode 334/500 terminado. Recompensa: -200.0
# Episode 335/500 terminado. Recompensa: -200.0
# Episode 336/500 terminado. Recompensa: -200.0
# Episode 337/500 terminado. Recompensa: -200.0
# Episode 338/500 terminado. Recompensa: -200.0
# Episode 339/500 terminado. Recompensa: -200.0
# Episode 340/500 terminado. Recompensa: -200.0
# Episode 341/500 terminado. Recompensa: -200.0
# Episode 342/500 terminado. Recompensa: -200.0
# Episode 343/500 terminado. Recompensa: -200.0
# Episode 344/500 terminado. Recompensa: -200.0
# Episode 345/500 terminado. Recompensa: -200.0
# Episode 346/500 terminado. Recompensa: -200.0
# Episode 347/500 terminado. Recompensa: -200.0
# Episode 348/500 terminado. Recompensa: -200.0
# Episode 349/500 terminado. Recompensa: -200.0
# Episode 350/500 terminado. Recompensa: -200.0
# Episode 351/500 terminado. Recompensa: -200.0
# Episode 352/500 terminado. Recompensa: -200.0
# Episode 353/500 terminado. Recompensa: -200.0
# Episode 354/500 terminado. Recompensa: -200.0
# Episode 355/500 terminado. Recompensa: -200.0
# Episode 356/500 terminado. Recompensa: -200.0
# Episode 357/500 terminado. Recompensa: -200.0
# Episode 358/500 terminado. Recompensa: -200.0
# Episode 359/500 terminado. Recompensa: -200.0
# Episode 360/500 terminado. Recompensa: -200.0
# Episode 361/500 terminado. Recompensa: -200.0
# Episode 362/500 terminado. Recompensa: -200.0
# Episode 363/500 terminado. Recompensa: -200.0
# Episode 364/500 terminado. Recompensa: -200.0
# Episode 365/500 terminado. Recompensa: -200.0
# Episode 366/500 terminado. Recompensa: -200.0
# Episode 367/500 terminado. Recompensa: -200.0
# Episode 368/500 terminado. Recompensa: -200.0
# Episode 369/500 terminado. Recompensa: -200.0
# Episode 370/500 terminado. Recompensa: -200.0
# Episode 371/500 terminado. Recompensa: -200.0
# Episode 372/500 terminado. Recompensa: -200.0
# Episode 373/500 terminado. Recompensa: -200.0
# Episode 374/500 terminado. Recompensa: -200.0
# Episode 375/500 terminado. Recompensa: -200.0
# Episode 376/500 terminado. Recompensa: -200.0
# Episode 377/500 terminado. Recompensa: -200.0
# Episode 378/500 terminado. Recompensa: -200.0
# Episode 379/500 terminado. Recompensa: -200.0
# Episode 380/500 terminado. Recompensa: -200.0
# Episode 381/500 terminado. Recompensa: -200.0
# Episode 382/500 terminado. Recompensa: -200.0
# Episode 383/500 terminado. Recompensa: -200.0
# Episode 384/500 terminado. Recompensa: -200.0
# Episode 385/500 terminado. Recompensa: -200.0
# Episode 386/500 terminado. Recompensa: -200.0
# Episode 387/500 terminado. Recompensa: -200.0
# Episode 388/500 terminado. Recompensa: -200.0
# Episode 389/500 terminado. Recompensa: -200.0
# Episode 390/500 terminado. Recompensa: -200.0
# Episode 391/500 terminado. Recompensa: -200.0
# Episode 392/500 terminado. Recompensa: -200.0
# Episode 393/500 terminado. Recompensa: -200.0
# Episode 394/500 terminado. Recompensa: -200.0
# Episode 395/500 terminado. Recompensa: -200.0
# Episode 396/500 terminado. Recompensa: -200.0
# Episode 397/500 terminado. Recompensa: -200.0
# Episode 398/500 terminado. Recompensa: -200.0
# Episode 399/500 terminado. Recompensa: -200.0
# Episode 400/500 terminado. Recompensa: -200.0
# Episode 401/500 terminado. Recompensa: -200.0
# Episode 402/500 terminado. Recompensa: -200.0
# Episode 403/500 terminado. Recompensa: -200.0
# Episode 404/500 terminado. Recompensa: -200.0
# Episode 405/500 terminado. Recompensa: -200.0
# Episode 406/500 terminado. Recompensa: -200.0
# Episode 407/500 terminado. Recompensa: -200.0
# Episode 408/500 terminado. Recompensa: -200.0
# Episode 409/500 terminado. Recompensa: -200.0
# Episode 410/500 terminado. Recompensa: -200.0
# Episode 411/500 terminado. Recompensa: -200.0
# Episode 412/500 terminado. Recompensa: -200.0
# Episode 413/500 terminado. Recompensa: -200.0
# Episode 414/500 terminado. Recompensa: -200.0
# Episode 415/500 terminado. Recompensa: -200.0
# Episode 416/500 terminado. Recompensa: -200.0
# Episode 417/500 terminado. Recompensa: -200.0
# Episode 418/500 terminado. Recompensa: -200.0
# Episode 419/500 terminado. Recompensa: -200.0
# Episode 420/500 terminado. Recompensa: -200.0
# Episode 421/500 terminado. Recompensa: -200.0
# Episode 422/500 terminado. Recompensa: -200.0
# Episode 423/500 terminado. Recompensa: -200.0
# Episode 424/500 terminado. Recompensa: -200.0
# Episode 425/500 terminado. Recompensa: -200.0
# Episode 426/500 terminado. Recompensa: -200.0
# Episode 427/500 terminado. Recompensa: -200.0
# Episode 428/500 terminado. Recompensa: -200.0
# Episode 429/500 terminado. Recompensa: -200.0
# Episode 430/500 terminado. Recompensa: -200.0
# Episode 431/500 terminado. Recompensa: -200.0
# Episode 432/500 terminado. Recompensa: -200.0
# Episode 433/500 terminado. Recompensa: -200.0
# Episode 434/500 terminado. Recompensa: -200.0
# Episode 435/500 terminado. Recompensa: -200.0
# Episode 436/500 terminado. Recompensa: -200.0
# Episode 437/500 terminado. Recompensa: -200.0
# Episode 438/500 terminado. Recompensa: -200.0
# Episode 439/500 terminado. Recompensa: -200.0
# Episode 440/500 terminado. Recompensa: -200.0
# Episode 441/500 terminado. Recompensa: -200.0
# Episode 442/500 terminado. Recompensa: -200.0
# Episode 443/500 terminado. Recompensa: -200.0
# Episode 444/500 terminado. Recompensa: -200.0
# Episode 445/500 terminado. Recompensa: -200.0
# Episode 446/500 terminado. Recompensa: -200.0
# Episode 447/500 terminado. Recompensa: -200.0
# Episode 448/500 terminado. Recompensa: -200.0
# Episode 449/500 terminado. Recompensa: -200.0
# Episode 450/500 terminado. Recompensa: -200.0
# Episode 451/500 terminado. Recompensa: -200.0
# Episode 452/500 terminado. Recompensa: -200.0
# Episode 453/500 terminado. Recompensa: -200.0
# Episode 454/500 terminado. Recompensa: -200.0
# Episode 455/500 terminado. Recompensa: -200.0
# Episode 456/500 terminado. Recompensa: -200.0
# Episode 457/500 terminado. Recompensa: -200.0
# Episode 458/500 terminado. Recompensa: -200.0
# Episode 459/500 terminado. Recompensa: -200.0
# Episode 460/500 terminado. Recompensa: -200.0
# Episode 461/500 terminado. Recompensa: -200.0
# Episode 462/500 terminado. Recompensa: -200.0
# Episode 463/500 terminado. Recompensa: -200.0
# Episode 464/500 terminado. Recompensa: -200.0
# Episode 465/500 terminado. Recompensa: -200.0
# Episode 466/500 terminado. Recompensa: -200.0
# Episode 467/500 terminado. Recompensa: -200.0
# Episode 468/500 terminado. Recompensa: -200.0
# Episode 469/500 terminado. Recompensa: -200.0
# Episode 470/500 terminado. Recompensa: -200.0
# Episode 471/500 terminado. Recompensa: -200.0
# Episode 472/500 terminado. Recompensa: -200.0
# Episode 473/500 terminado. Recompensa: -200.0
# Episode 474/500 terminado. Recompensa: -200.0
# Episode 475/500 terminado. Recompensa: -200.0
# Episode 476/500 terminado. Recompensa: -200.0
# Episode 477/500 terminado. Recompensa: -200.0
# Episode 478/500 terminado. Recompensa: -200.0
# Episode 479/500 terminado. Recompensa: -200.0
# Episode 480/500 terminado. Recompensa: -200.0
# Episode 481/500 terminado. Recompensa: -200.0
# Episode 482/500 terminado. Recompensa: -200.0
# Episode 483/500 terminado. Recompensa: -200.0
# Episode 484/500 terminado. Recompensa: -200.0
# Episode 485/500 terminado. Recompensa: -200.0
# Episode 486/500 terminado. Recompensa: -200.0
# Episode 487/500 terminado. Recompensa: -200.0
# Episode 488/500 terminado. Recompensa: -200.0
# Episode 489/500 terminado. Recompensa: -200.0
# Episode 490/500 terminado. Recompensa: -200.0
# Episode 491/500 terminado. Recompensa: -200.0
# Episode 492/500 terminado. Recompensa: -200.0
# Episode 493/500 terminado. Recompensa: -200.0
# Episode 494/500 terminado. Recompensa: -200.0
# Episode 495/500 terminado. Recompensa: -200.0
# Episode 496/500 terminado. Recompensa: -200.0
# Episode 497/500 terminado. Recompensa: -200.0
# Episode 498/500 terminado. Recompensa: -200.0
# Episode 499/500 terminado. Recompensa: -200.0
# Episode 500/500 terminado. Recompensa: -200.0
#
# === Experimento 3 ===
# Episode 1/500 terminado. Recompensa: -200.0
# Episode 2/500 terminado. Recompensa: -200.0
# Episode 3/500 terminado. Recompensa: -200.0
# Episode 4/500 terminado. Recompensa: -200.0
# Episode 5/500 terminado. Recompensa: -200.0
# Episode 6/500 terminado. Recompensa: -200.0
# Episode 7/500 terminado. Recompensa: -200.0
# Episode 8/500 terminado. Recompensa: -200.0
# Episode 9/500 terminado. Recompensa: -200.0
# Episode 10/500 terminado. Recompensa: -200.0
# Episode 11/500 terminado. Recompensa: -200.0
# Episode 12/500 terminado. Recompensa: -200.0
# Episode 13/500 terminado. Recompensa: -200.0
# Episode 14/500 terminado. Recompensa: -200.0
# Episode 15/500 terminado. Recompensa: -200.0
# Episode 16/500 terminado. Recompensa: -200.0
# Episode 17/500 terminado. Recompensa: -200.0
# Episode 18/500 terminado. Recompensa: -200.0
# Episode 19/500 terminado. Recompensa: -200.0
# Episode 20/500 terminado. Recompensa: -200.0
# Episode 21/500 terminado. Recompensa: -200.0
# Episode 22/500 terminado. Recompensa: -200.0
# Episode 23/500 terminado. Recompensa: -200.0
# Episode 24/500 terminado. Recompensa: -200.0
# Episode 25/500 terminado. Recompensa: -200.0
# Episode 26/500 terminado. Recompensa: -200.0
# Episode 27/500 terminado. Recompensa: -200.0
# Episode 28/500 terminado. Recompensa: -200.0
# Episode 29/500 terminado. Recompensa: -200.0
# Episode 30/500 terminado. Recompensa: -200.0
# Episode 31/500 terminado. Recompensa: -200.0
# Episode 32/500 terminado. Recompensa: -200.0
# Episode 33/500 terminado. Recompensa: -200.0
# Episode 34/500 terminado. Recompensa: -200.0
# Episode 35/500 terminado. Recompensa: -200.0
# Episode 36/500 terminado. Recompensa: -200.0
# Episode 37/500 terminado. Recompensa: -200.0
# Episode 38/500 terminado. Recompensa: -200.0
# Episode 39/500 terminado. Recompensa: -200.0
# Episode 40/500 terminado. Recompensa: -200.0
# Episode 41/500 terminado. Recompensa: -200.0
# Episode 42/500 terminado. Recompensa: -200.0
# Episode 43/500 terminado. Recompensa: -200.0
# Episode 44/500 terminado. Recompensa: -200.0
# Episode 45/500 terminado. Recompensa: -200.0
# Episode 46/500 terminado. Recompensa: -200.0
# Episode 47/500 terminado. Recompensa: -200.0
# ...
# Episode 426/500 terminado. Recompensa: -200.0
# Episode 427/500 terminado. Recompensa: -200.0
# Episode 428/500 terminado. Recompensa: -200.0
# Episode 429/500 terminado. Recompensa: -200.0
# Episode 430/500 terminado. Recompensa: -200.0
# Episode 431/500 terminado. Recompensa: -200.0
# Episode 432/500 terminado. Recompensa: -200.0
# Episode 433/500 terminado. Recompensa: -200.0
# Episode 434/500 terminado. Recompensa: -200.0
# Episode 435/500 terminado. Recompensa: -200.0
# Episode 436/500 terminado. Recompensa: -200.0
# Episode 437/500 terminado. Recompensa: -200.0
# Episode 438/500 terminado. Recompensa: -200.0
# Episode 439/500 terminado. Recompensa: -200.0
# Episode 440/500 terminado. Recompensa: -200.0
# Episode 441/500 terminado. Recompensa: -200.0
# Episode 442/500 terminado. Recompensa: -200.0
# Episode 443/500 terminado. Recompensa: -200.0
# Episode 444/500 terminado. Recompensa: -200.0
# Episode 445/500 terminado. Recompensa: -200.0
# Episode 446/500 terminado. Recompensa: -200.0
# Episode 447/500 terminado. Recompensa: -200.0
# Episode 448/500 terminado. Recompensa: -200.0
# Episode 449/500 terminado. Recompensa: -200.0
# Episode 450/500 terminado. Recompensa: -200.0
# Episode 451/500 terminado. Recompensa: -200.0
# Episode 452/500 terminado. Recompensa: -200.0
# Episode 453/500 terminado. Recompensa: -200.0
# Episode 454/500 terminado. Recompensa: -200.0
# Episode 455/500 terminado. Recompensa: -200.0
# Episode 456/500 terminado. Recompensa: -200.0
# Episode 457/500 terminado. Recompensa: -200.0
# Episode 458/500 terminado. Recompensa: -200.0
# Episode 459/500 terminado. Recompensa: -200.0
# Episode 460/500 terminado. Recompensa: -200.0
# Episode 461/500 terminado. Recompensa: -200.0
# Episode 462/500 terminado. Recompensa: -200.0
# Episode 463/500 terminado. Recompensa: -200.0
# Episode 464/500 terminado. Recompensa: -200.0
# Episode 465/500 terminado. Recompensa: -200.0
# Episode 466/500 terminado. Recompensa: -200.0
# Episode 467/500 terminado. Recompensa: -200.0
# Episode 468/500 terminado. Recompensa: -200.0
# Episode 469/500 terminado. Recompensa: -200.0
# Episode 470/500 terminado. Recompensa: -200.0
# Episode 471/500 terminado. Recompensa: -200.0
# Episode 472/500 terminado. Recompensa: -200.0
# Episode 473/500 terminado. Recompensa: -200.0
# Episode 474/500 terminado. Recompensa: -200.0
# Episode 475/500 terminado. Recompensa: -200.0
# Episode 476/500 terminado. Recompensa: -200.0
# Episode 477/500 terminado. Recompensa: -200.0
# Episode 478/500 terminado. Recompensa: -200.0
# Episode 479/500 terminado. Recompensa: -200.0
# Episode 480/500 terminado. Recompensa: -200.0
# Episode 481/500 terminado. Recompensa: -200.0
# Episode 482/500 terminado. Recompensa: -200.0
# Episode 483/500 terminado. Recompensa: -200.0
# Episode 484/500 terminado. Recompensa: -200.0
# Episode 485/500 terminado. Recompensa: -200.0
# Episode 486/500 terminado. Recompensa: -200.0
# Episode 487/500 terminado. Recompensa: -200.0
# Episode 488/500 terminado. Recompensa: -200.0
# Episode 489/500 terminado. Recompensa: -200.0
# Episode 490/500 terminado. Recompensa: -200.0
# Episode 491/500 terminado. Recompensa: -200.0
# Episode 492/500 terminado. Recompensa: -200.0
# Episode 493/500 terminado. Recompensa: -200.0
# Episode 494/500 terminado. Recompensa: -200.0
# Episode 495/500 terminado. Recompensa: -200.0
# Episode 496/500 terminado. Recompensa: -200.0
# Episode 497/500 terminado. Recompensa: -200.0
# Episode 498/500 terminado. Recompensa: -200.0
# Episode 499/500 terminado. Recompensa: -200.0
# Episode 500/500 terminado. Recompensa: -200.0
#
# === Experimento 10 ===
# Episode 1/500 terminado. Recompensa: -200.0
# Episode 2/500 terminado. Recompensa: -200.0
# Episode 3/500 terminado. Recompensa: -200.0
# Episode 4/500 terminado. Recompensa: -200.0
# Episode 5/500 terminado. Recompensa: -200.0
# Episode 6/500 terminado. Recompensa: -200.0
# Episode 7/500 terminado. Recompensa: -200.0
# Episode 8/500 terminado. Recompensa: -200.0
# Episode 9/500 terminado. Recompensa: -200.0
# Episode 10/500 terminado. Recompensa: -200.0
# Episode 11/500 terminado. Recompensa: -200.0
# Episode 12/500 terminado. Recompensa: -200.0
# Episode 13/500 terminado. Recompensa: -200.0
# Episode 14/500 terminado. Recompensa: -200.0
# Episode 15/500 terminado. Recompensa: -200.0
# Episode 16/500 terminado. Recompensa: -200.0
# Episode 17/500 terminado. Recompensa: -200.0
# Episode 18/500 terminado. Recompensa: -200.0
# Episode 19/500 terminado. Recompensa: -200.0
# Episode 20/500 terminado. Recompensa: -200.0
# Episode 21/500 terminado. Recompensa: -200.0
# Episode 22/500 terminado. Recompensa: -200.0
# Episode 23/500 terminado. Recompensa: -200.0
# Episode 24/500 terminado. Recompensa: -200.0
# Episode 25/500 terminado. Recompensa: -200.0
# Episode 26/500 terminado. Recompensa: -200.0
# Episode 27/500 terminado. Recompensa: -200.0
# Episode 28/500 terminado. Recompensa: -200.0
# Episode 29/500 terminado. Recompensa: -200.0
# Episode 30/500 terminado. Recompensa: -200.0
# Episode 31/500 terminado. Recompensa: -200.0
# Episode 32/500 terminado. Recompensa: -200.0
# Episode 33/500 terminado. Recompensa: -200.0
# Episode 34/500 terminado. Recompensa: -200.0
# Episode 35/500 terminado. Recompensa: -200.0
# Episode 36/500 terminado. Recompensa: -200.0
# Episode 37/500 terminado. Recompensa: -200.0
# Episode 38/500 terminado. Recompensa: -200.0
# Episode 39/500 terminado. Recompensa: -200.0
# Episode 40/500 terminado. Recompensa: -200.0
# Episode 41/500 terminado. Recompensa: -200.0
# Episode 42/500 terminado. Recompensa: -200.0
# Episode 43/500 terminado. Recompensa: -200.0
# Episode 44/500 terminado. Recompensa: -200.0
# Episode 45/500 terminado. Recompensa: -200.0
# Episode 46/500 terminado. Recompensa: -200.0
# Episode 47/500 terminado. Recompensa: -200.0
# Episode 48/500 terminado. Recompensa: -200.0
# Episode 49/500 terminado. Recompensa: -200.0
# Episode 50/500 terminado. Recompensa: -200.0
# Episode 51/500 terminado. Recompensa: -200.0
# Episode 52/500 terminado. Recompensa: -200.0
# Episode 53/500 terminado. Recompensa: -200.0
# Episode 54/500 terminado. Recompensa: -200.0
# Episode 55/500 terminado. Recompensa: -200.0
# Episode 56/500 terminado. Recompensa: -200.0
# Episode 57/500 terminado. Recompensa: -200.0
# Episode 58/500 terminado. Recompensa: -200.0
# Episode 59/500 terminado. Recompensa: -200.0
# Episode 60/500 terminado. Recompensa: -200.0
# Episode 61/500 terminado. Recompensa: -200.0
# Episode 62/500 terminado. Recompensa: -200.0
# Episode 63/500 terminado. Recompensa: -200.0
# Episode 64/500 terminado. Recompensa: -200.0
# Episode 65/500 terminado. Recompensa: -200.0
# Episode 66/500 terminado. Recompensa: -200.0
# Episode 67/500 terminado. Recompensa: -200.0
# Episode 68/500 terminado. Recompensa: -200.0
# Episode 69/500 terminado. Recompensa: -200.0
# Episode 70/500 terminado. Recompensa: -200.0
# Episode 71/500 terminado. Recompensa: -200.0
# Episode 72/500 terminado. Recompensa: -200.0
# Episode 73/500 terminado. Recompensa: -200.0
# Episode 74/500 terminado. Recompensa: -200.0
# Episode 75/500 terminado. Recompensa: -200.0
# Episode 76/500 terminado. Recompensa: -200.0
# Episode 77/500 terminado. Recompensa: -200.0
# Episode 78/500 terminado. Recompensa: -200.0
# Episode 79/500 terminado. Recompensa: -200.0
# Episode 80/500 terminado. Recompensa: -200.0
# Episode 81/500 terminado. Recompensa: -200.0
# Episode 82/500 terminado. Recompensa: -200.0
# Episode 83/500 terminado. Recompensa: -200.0
# Episode 84/500 terminado. Recompensa: -200.0
# Episode 85/500 terminado. Recompensa: -200.0
# Episode 86/500 terminado. Recompensa: -200.0
# Episode 87/500 terminado. Recompensa: -200.0
# Episode 88/500 terminado. Recompensa: -200.0
# Episode 89/500 terminado. Recompensa: -200.0
# Episode 90/500 terminado. Recompensa: -200.0
# Episode 91/500 terminado. Recompensa: -200.0
# Episode 92/500 terminado. Recompensa: -200.0
# Episode 93/500 terminado. Recompensa: -200.0
# Episode 94/500 terminado. Recompensa: -200.0
# Episode 95/500 terminado. Recompensa: -200.0
# Episode 96/500 terminado. Recompensa: -200.0
# Episode 97/500 terminado. Recompensa: -200.0
# Episode 98/500 terminado. Recompensa: -200.0
# Episode 99/500 terminado. Recompensa: -200.0
# Episode 100/500 terminado. Recompensa: -200.0
# Episode 101/500 terminado. Recompensa: -200.0
# Episode 102/500 terminado. Recompensa: -200.0
# Episode 103/500 terminado. Recompensa: -200.0
# Episode 104/500 terminado. Recompensa: -200.0
# Episode 105/500 terminado. Recompensa: -200.0
# Episode 106/500 terminado. Recompensa: -200.0
# Episode 107/500 terminado. Recompensa: -200.0
# Episode 108/500 terminado. Recompensa: -200.0
# Episode 109/500 terminado. Recompensa: -200.0
# Episode 110/500 terminado. Recompensa: -200.0
# Episode 111/500 terminado. Recompensa: -200.0
# Episode 112/500 terminado. Recompensa: -200.0
# Episode 113/500 terminado. Recompensa: -200.0
# Episode 114/500 terminado. Recompensa: -200.0
# Episode 115/500 terminado. Recompensa: -200.0
# Episode 116/500 terminado. Recompensa: -200.0
# Episode 117/500 terminado. Recompensa: -200.0
# Episode 118/500 terminado. Recompensa: -200.0
# Episode 119/500 terminado. Recompensa: -200.0
# Episode 120/500 terminado. Recompensa: -200.0
# Episode 121/500 terminado. Recompensa: -200.0
# Episode 122/500 terminado. Recompensa: -200.0
# Episode 123/500 terminado. Recompensa: -200.0
# Episode 124/500 terminado. Recompensa: -200.0
# Episode 125/500 terminado. Recompensa: -200.0
# Episode 126/500 terminado. Recompensa: -200.0
# Episode 127/500 terminado. Recompensa: -200.0
# Episode 128/500 terminado. Recompensa: -200.0
# Episode 129/500 terminado. Recompensa: -200.0
# Episode 130/500 terminado. Recompensa: -200.0
# Episode 131/500 terminado. Recompensa: -200.0
# Episode 132/500 terminado. Recompensa: -200.0
# Episode 133/500 terminado. Recompensa: -200.0
# Episode 134/500 terminado. Recompensa: -200.0
# Episode 135/500 terminado. Recompensa: -200.0
# Episode 136/500 terminado. Recompensa: -200.0
# Episode 137/500 terminado. Recompensa: -200.0
# Episode 138/500 terminado. Recompensa: -200.0
# Episode 139/500 terminado. Recompensa: -200.0
# Episode 140/500 terminado. Recompensa: -200.0
# Episode 141/500 terminado. Recompensa: -200.0
# Episode 142/500 terminado. Recompensa: -200.0
# Episode 143/500 terminado. Recompensa: -200.0
# Episode 144/500 terminado. Recompensa: -200.0
# Episode 145/500 terminado. Recompensa: -200.0
# Episode 146/500 terminado. Recompensa: -200.0
# Episode 147/500 terminado. Recompensa: -200.0
# Episode 148/500 terminado. Recompensa: -200.0
# Episode 149/500 terminado. Recompensa: -200.0
# Episode 150/500 terminado. Recompensa: -200.0
# Episode 151/500 terminado. Recompensa: -200.0
# Episode 152/500 terminado. Recompensa: -200.0
# Episode 153/500 terminado. Recompensa: -200.0
# Episode 154/500 terminado. Recompensa: -200.0
# Episode 155/500 terminado. Recompensa: -200.0
# Episode 156/500 terminado. Recompensa: -200.0
# Episode 157/500 terminado. Recompensa: -200.0
# Episode 158/500 terminado. Recompensa: -200.0
# Episode 159/500 terminado. Recompensa: -200.0
# Episode 160/500 terminado. Recompensa: -200.0
# Episode 161/500 terminado. Recompensa: -200.0
# Episode 162/500 terminado. Recompensa: -200.0
# Episode 163/500 terminado. Recompensa: -200.0
# Episode 164/500 terminado. Recompensa: -200.0
# Episode 165/500 terminado. Recompensa: -200.0
# Episode 166/500 terminado. Recompensa: -200.0
# Episode 167/500 terminado. Recompensa: -200.0
# Episode 168/500 terminado. Recompensa: -200.0
# Episode 169/500 terminado. Recompensa: -200.0
# Episode 170/500 terminado. Recompensa: -200.0
# Episode 171/500 terminado. Recompensa: -200.0
# Episode 172/500 terminado. Recompensa: -200.0
# Episode 173/500 terminado. Recompensa: -200.0
# Episode 174/500 terminado. Recompensa: -200.0
# Episode 175/500 terminado. Recompensa: -200.0
# Episode 176/500 terminado. Recompensa: -200.0
# Episode 177/500 terminado. Recompensa: -200.0
# Episode 178/500 terminado. Recompensa: -200.0
# Episode 179/500 terminado. Recompensa: -200.0
# Episode 180/500 terminado. Recompensa: -200.0
# Episode 181/500 terminado. Recompensa: -200.0
# Episode 182/500 terminado. Recompensa: -200.0
# Episode 183/500 terminado. Recompensa: -200.0
# Episode 184/500 terminado. Recompensa: -200.0
# Episode 185/500 terminado. Recompensa: -200.0
# Episode 186/500 terminado. Recompensa: -200.0
# Episode 187/500 terminado. Recompensa: -200.0
# Episode 188/500 terminado. Recompensa: -200.0
# Episode 189/500 terminado. Recompensa: -200.0
# Episode 190/500 terminado. Recompensa: -200.0
# Episode 191/500 terminado. Recompensa: -200.0
# Episode 192/500 terminado. Recompensa: -200.0
# Episode 193/500 terminado. Recompensa: -200.0
# Episode 194/500 terminado. Recompensa: -200.0
# Episode 195/500 terminado. Recompensa: -200.0
# Episode 196/500 terminado. Recompensa: -200.0
# Episode 197/500 terminado. Recompensa: -200.0
# Episode 198/500 terminado. Recompensa: -200.0
# Episode 199/500 terminado. Recompensa: -200.0
# Episode 200/500 terminado. Recompensa: -200.0
# Episode 201/500 terminado. Recompensa: -200.0
# Episode 202/500 terminado. Recompensa: -200.0
# Episode 203/500 terminado. Recompensa: -200.0
# Episode 204/500 terminado. Recompensa: -200.0
# Episode 205/500 terminado. Recompensa: -200.0
# Episode 206/500 terminado. Recompensa: -200.0
# Episode 207/500 terminado. Recompensa: -200.0
# Episode 208/500 terminado. Recompensa: -200.0
# Episode 209/500 terminado. Recompensa: -200.0
# Episode 210/500 terminado. Recompensa: -200.0
# Episode 211/500 terminado. Recompensa: -200.0
# Episode 212/500 terminado. Recompensa: -200.0
# Episode 213/500 terminado. Recompensa: -200.0
# Episode 214/500 terminado. Recompensa: -200.0
# Episode 215/500 terminado. Recompensa: -200.0
# Episode 216/500 terminado. Recompensa: -200.0
# Episode 217/500 terminado. Recompensa: -200.0
# Episode 218/500 terminado. Recompensa: -200.0
# Episode 219/500 terminado. Recompensa: -200.0
# Episode 220/500 terminado. Recompensa: -200.0
# Episode 221/500 terminado. Recompensa: -200.0
# Episode 222/500 terminado. Recompensa: -200.0
# Episode 223/500 terminado. Recompensa: -200.0
# Episode 224/500 terminado. Recompensa: -200.0
# Episode 225/500 terminado. Recompensa: -200.0
# Episode 226/500 terminado. Recompensa: -200.0
# Episode 227/500 terminado. Recompensa: -200.0
# Episode 228/500 terminado. Recompensa: -200.0
# Episode 229/500 terminado. Recompensa: -200.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 123
#     121 # Crear un nuevo entorno para cada experimento
#     122 env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.5)
# --> 123 Q, training_rewards = dyna_q_train(env, num_episodes=num_episodes, alpha=0.01, gamma=0.99, epsilon=0.4, planning_steps=10)
#     124 all_training_rewards.append(training_rewards)
#     125 # Evaluar la política resultante
#
# Cell In[14], line 80, in dyna_q_train(env, num_episodes, alpha, gamma, epsilon, planning_steps)
#      78     sampled_action = random.randint(0, n_actions - 1)
#      79     r_sampled, s_prime_sampled = model[sampled_state][sampled_action]
# ---> 80     best_a_sampled = np.argmax(Q[s_prime_sampled])
#      81     Q[sampled_state, sampled_action] += alpha * (r_sampled + gamma * Q[s_prime_sampled, best_a_sampled]
#      82                                                  - Q[sampled_state, sampled_action])
#      84 state = next_state
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\core\fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
import numpy as np
import random
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd

# Parámetros de discretización (ajustables)
NUM_BINS_POS = 20    # Puedes aumentar a 30 o más para mayor precisión
NUM_BINS_VEL = 20

# Crear los bins para cada dimensión (se usa num_bins+1 para incluir los extremos)
bins_pos = np.linspace(-1.2, 0.6, NUM_BINS_POS + 1)
bins_vel = np.linspace(-0.07, 0.07, NUM_BINS_VEL + 1)

def discretize_state(state, bins_pos, bins_vel):
    """
    Convierte un estado continuo [posición, velocidad] en un índice discreto.
    """
    pos, vel = state
    pos_bin = np.clip(np.digitize(pos, bins_pos) - 1, 0, NUM_BINS_POS - 1)
    vel_bin = np.clip(np.digitize(vel, bins_vel) - 1, 0, NUM_BINS_VEL - 1)
    return pos_bin * NUM_BINS_VEL + vel_bin

def epsilon_greedy(Q_values, epsilon):
    """
    Selecciona una acción según la política epsilon-greedy.
    """
    if random.random() < epsilon:
        return random.randint(0, len(Q_values) - 1)
    else:
        return np.argmax(Q_values)

def dyna_q_train(env, num_episodes=500, alpha=0.1, gamma=0.99, epsilon=1.0, planning_steps=20):
    """
    Entrena Dyna-Q en un entorno discretizado.
    Retorna:
      Q: la tabla Q aprendida.
      training_rewards: lista con la recompensa total obtenida en cada episodio.
    """
    n_states = NUM_BINS_POS * NUM_BINS_VEL  
    n_actions = env.action_space.n

    Q = np.zeros((n_states, n_actions))
    model = {s: {a: (0.0, s) for a in range(n_actions)} for s in range(n_states)}
    
    training_rewards = []  # Recompensa total por episodio
    
    # Parámetros para decaimiento de epsilon
    epsilon_min = 0.05
    epsilon_decay = 0.995
    
    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = discretize_state(obs, bins_pos, bins_vel)
        done = False
        total_reward = 0.0
        
        while not done:
            action = epsilon_greedy(Q[state], epsilon)
            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            next_state = discretize_state(next_obs, bins_pos, bins_vel)
            total_reward += reward
            
            best_next_action = np.argmax(Q[next_state])
            Q[state, action] += alpha * (reward + gamma * Q[next_state, best_next_action] - Q[state, action])
            
            model[state][action] = (reward, next_state)
            
            for _ in range(planning_steps):
                sampled_state = random.randint(0, n_states - 1)
                sampled_action = random.randint(0, n_actions - 1)
                r_sampled, s_prime_sampled = model[sampled_state][sampled_action]
                best_a_sampled = np.argmax(Q[s_prime_sampled])
                Q[sampled_state, sampled_action] += alpha * (r_sampled + gamma * Q[s_prime_sampled, best_a_sampled]
                                                             - Q[sampled_state, sampled_action])
                
            state = next_state
        
        training_rewards.append(total_reward)
        # Actualizar epsilon (decaimiento)
        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        print(f"Episode {episode+1}/{num_episodes} terminado. Recompensa: {total_reward}, epsilon: {epsilon:.3f}")
        
    return Q, training_rewards

def evaluate_policy(env, Q, render=False):
    """
    Evalúa la política resultante (acción greedy) y retorna la recompensa total.
    """
    obs, _ = env.reset()
    state = discretize_state(obs, bins_pos, bins_vel)
    done = False
    total_reward = 0.0
    while not done:
        action = np.argmax(Q[state])  # Política greedy
        next_obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        total_reward += reward
        state = discretize_state(next_obs, bins_pos, bins_vel)
        if render:
            env.render()
    return total_reward

# Parámetros para los experimentos
num_experimentos = 10
num_episodes = 500

all_training_rewards = []
evaluation_rewards = []

for exp in range(num_experimentos):
    print(f"\n=== Experimento {exp+1} ===")
    env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.1)
    Q, training_rewards = dyna_q_train(env, num_episodes=num_episodes, alpha=0.8, gamma=0.8, epsilon=1.0, planning_steps=25)
    all_training_rewards.append(training_rewards)
    eval_reward = evaluate_policy(env, Q)
    evaluation_rewards.append(eval_reward)
    env.close()

all_training_rewards = np.array(all_training_rewards)
mean_training_rewards = np.mean(all_training_rewards, axis=0)
std_training_rewards = np.std(all_training_rewards, axis=0)

plt.figure(figsize=(10, 5))
episodes = np.arange(1, num_episodes + 1)
plt.plot(episodes, mean_training_rewards, label="Recompensa Promedio")
plt.fill_between(episodes, mean_training_rewards - std_training_rewards, mean_training_rewards + std_training_rewards,
                 alpha=0.2, label="±1 Desv. Estándar")
plt.xlabel("Episodios")
plt.ylabel("Recompensa Total")
plt.title("Curva de Recompensa durante el Entrenamiento (Dyna-Q en MountainCar)")
plt.legend()
plt.show()

df = pd.DataFrame({
    "Experimento": np.arange(1, num_experimentos + 1),
    "Recompensa Evaluación": evaluation_rewards
})
mean_eval = np.mean(evaluation_rewards)
std_eval = np.std(evaluation_rewards)
summary_df = pd.DataFrame({
    "Media Recompensa": [mean_eval],
    "Desviación Estándar": [std_eval]
})

print("Resultados de Evaluación por Experimento:")
print(df)
print("\nResumen (Media y Desviación Estándar) de la Recompensa Evaluación:")
print(summary_df)
# Out:
# === Experimento 1 ===
# Episode 1/500 terminado. Recompensa: -200.0, epsilon: 0.995
# Episode 2/500 terminado. Recompensa: -200.0, epsilon: 0.990
# Episode 3/500 terminado. Recompensa: -200.0, epsilon: 0.985
# Episode 4/500 terminado. Recompensa: -200.0, epsilon: 0.980
# Episode 5/500 terminado. Recompensa: -200.0, epsilon: 0.975
# Episode 6/500 terminado. Recompensa: -200.0, epsilon: 0.970
# Episode 7/500 terminado. Recompensa: -200.0, epsilon: 0.966
# Episode 8/500 terminado. Recompensa: -200.0, epsilon: 0.961
# Episode 9/500 terminado. Recompensa: -200.0, epsilon: 0.956
# Episode 10/500 terminado. Recompensa: -200.0, epsilon: 0.951
# Episode 11/500 terminado. Recompensa: -200.0, epsilon: 0.946
# Episode 12/500 terminado. Recompensa: -200.0, epsilon: 0.942
# Episode 13/500 terminado. Recompensa: -200.0, epsilon: 0.937
# Episode 14/500 terminado. Recompensa: -200.0, epsilon: 0.932
# Episode 15/500 terminado. Recompensa: -200.0, epsilon: 0.928
# Episode 16/500 terminado. Recompensa: -200.0, epsilon: 0.923
# Episode 17/500 terminado. Recompensa: -200.0, epsilon: 0.918
# Episode 18/500 terminado. Recompensa: -200.0, epsilon: 0.914
# Episode 19/500 terminado. Recompensa: -200.0, epsilon: 0.909
# Episode 20/500 terminado. Recompensa: -200.0, epsilon: 0.905
# Episode 21/500 terminado. Recompensa: -200.0, epsilon: 0.900
# Episode 22/500 terminado. Recompensa: -200.0, epsilon: 0.896
# Episode 23/500 terminado. Recompensa: -200.0, epsilon: 0.891
# Episode 24/500 terminado. Recompensa: -200.0, epsilon: 0.887
# Episode 25/500 terminado. Recompensa: -200.0, epsilon: 0.882
# Episode 26/500 terminado. Recompensa: -200.0, epsilon: 0.878
# Episode 27/500 terminado. Recompensa: -200.0, epsilon: 0.873
# Episode 28/500 terminado. Recompensa: -200.0, epsilon: 0.869
# Episode 29/500 terminado. Recompensa: -200.0, epsilon: 0.865
# Episode 30/500 terminado. Recompensa: -200.0, epsilon: 0.860
# Episode 31/500 terminado. Recompensa: -200.0, epsilon: 0.856
# Episode 32/500 terminado. Recompensa: -200.0, epsilon: 0.852
# Episode 33/500 terminado. Recompensa: -200.0, epsilon: 0.848
# Episode 34/500 terminado. Recompensa: -200.0, epsilon: 0.843
# Episode 35/500 terminado. Recompensa: -200.0, epsilon: 0.839
# Episode 36/500 terminado. Recompensa: -200.0, epsilon: 0.835
# Episode 37/500 terminado. Recompensa: -200.0, epsilon: 0.831
# Episode 38/500 terminado. Recompensa: -200.0, epsilon: 0.827
# Episode 39/500 terminado. Recompensa: -200.0, epsilon: 0.822
# Episode 40/500 terminado. Recompensa: -200.0, epsilon: 0.818
# Episode 41/500 terminado. Recompensa: -200.0, epsilon: 0.814
# Episode 42/500 terminado. Recompensa: -200.0, epsilon: 0.810
# Episode 43/500 terminado. Recompensa: -200.0, epsilon: 0.806
# Episode 44/500 terminado. Recompensa: -200.0, epsilon: 0.802
# Episode 45/500 terminado. Recompensa: -200.0, epsilon: 0.798
# Episode 46/500 terminado. Recompensa: -200.0, epsilon: 0.794
# Episode 47/500 terminado. Recompensa: -200.0, epsilon: 0.790
# Episode 48/500 terminado. Recompensa: -200.0, epsilon: 0.786
# Episode 49/500 terminado. Recompensa: -200.0, epsilon: 0.782
# Episode 50/500 terminado. Recompensa: -200.0, epsilon: 0.778
# Episode 51/500 terminado. Recompensa: -200.0, epsilon: 0.774
# Episode 52/500 terminado. Recompensa: -200.0, epsilon: 0.771
# Episode 53/500 terminado. Recompensa: -200.0, epsilon: 0.767
# Episode 54/500 terminado. Recompensa: -200.0, epsilon: 0.763
# Episode 55/500 terminado. Recompensa: -200.0, epsilon: 0.759
# Episode 56/500 terminado. Recompensa: -200.0, epsilon: 0.755
# Episode 57/500 terminado. Recompensa: -200.0, epsilon: 0.751
# Episode 58/500 terminado. Recompensa: -200.0, epsilon: 0.748
# Episode 59/500 terminado. Recompensa: -200.0, epsilon: 0.744
# Episode 60/500 terminado. Recompensa: -200.0, epsilon: 0.740
# Episode 61/500 terminado. Recompensa: -200.0, epsilon: 0.737
# Episode 62/500 terminado. Recompensa: -200.0, epsilon: 0.733
# Episode 63/500 terminado. Recompensa: -200.0, epsilon: 0.729
# Episode 64/500 terminado. Recompensa: -200.0, epsilon: 0.726
# Episode 65/500 terminado. Recompensa: -200.0, epsilon: 0.722
# Episode 66/500 terminado. Recompensa: -200.0, epsilon: 0.718
# Episode 67/500 terminado. Recompensa: -200.0, epsilon: 0.715
# Episode 68/500 terminado. Recompensa: -200.0, epsilon: 0.711
# Episode 69/500 terminado. Recompensa: -200.0, epsilon: 0.708
# Episode 70/500 terminado. Recompensa: -200.0, epsilon: 0.704
# Episode 71/500 terminado. Recompensa: -200.0, epsilon: 0.701
# Episode 72/500 terminado. Recompensa: -200.0, epsilon: 0.697
# Episode 73/500 terminado. Recompensa: -200.0, epsilon: 0.694
# Episode 74/500 terminado. Recompensa: -200.0, epsilon: 0.690
# Episode 75/500 terminado. Recompensa: -200.0, epsilon: 0.687
# Episode 76/500 terminado. Recompensa: -200.0, epsilon: 0.683
# Episode 77/500 terminado. Recompensa: -200.0, epsilon: 0.680
# Episode 78/500 terminado. Recompensa: -200.0, epsilon: 0.676
# Episode 79/500 terminado. Recompensa: -200.0, epsilon: 0.673
# Episode 80/500 terminado. Recompensa: -200.0, epsilon: 0.670
# Episode 81/500 terminado. Recompensa: -200.0, epsilon: 0.666
# Episode 82/500 terminado. Recompensa: -200.0, epsilon: 0.663
# Episode 83/500 terminado. Recompensa: -200.0, epsilon: 0.660
# Episode 84/500 terminado. Recompensa: -200.0, epsilon: 0.656
# Episode 85/500 terminado. Recompensa: -200.0, epsilon: 0.653
# Episode 86/500 terminado. Recompensa: -200.0, epsilon: 0.650
# Episode 87/500 terminado. Recompensa: -200.0, epsilon: 0.647
# Episode 88/500 terminado. Recompensa: -200.0, epsilon: 0.643
# Episode 89/500 terminado. Recompensa: -200.0, epsilon: 0.640
# Episode 90/500 terminado. Recompensa: -200.0, epsilon: 0.637
# Episode 91/500 terminado. Recompensa: -200.0, epsilon: 0.634
# Episode 92/500 terminado. Recompensa: -200.0, epsilon: 0.631
# Episode 93/500 terminado. Recompensa: -200.0, epsilon: 0.627
# Episode 94/500 terminado. Recompensa: -200.0, epsilon: 0.624
# Episode 95/500 terminado. Recompensa: -200.0, epsilon: 0.621
# Episode 96/500 terminado. Recompensa: -200.0, epsilon: 0.618
# Episode 97/500 terminado. Recompensa: -200.0, epsilon: 0.615
# Episode 98/500 terminado. Recompensa: -200.0, epsilon: 0.612
# Episode 99/500 terminado. Recompensa: -200.0, epsilon: 0.609
# Episode 100/500 terminado. Recompensa: -200.0, epsilon: 0.606
# Episode 101/500 terminado. Recompensa: -200.0, epsilon: 0.603
# Episode 102/500 terminado. Recompensa: -200.0, epsilon: 0.600
# Episode 103/500 terminado. Recompensa: -200.0, epsilon: 0.597
# Episode 104/500 terminado. Recompensa: -200.0, epsilon: 0.594
# Episode 105/500 terminado. Recompensa: -200.0, epsilon: 0.591
# Episode 106/500 terminado. Recompensa: -200.0, epsilon: 0.588
# Episode 107/500 terminado. Recompensa: -200.0, epsilon: 0.585
# Episode 108/500 terminado. Recompensa: -200.0, epsilon: 0.582
# Episode 109/500 terminado. Recompensa: -200.0, epsilon: 0.579
# Episode 110/500 terminado. Recompensa: -200.0, epsilon: 0.576
# Episode 111/500 terminado. Recompensa: -200.0, epsilon: 0.573
# Episode 112/500 terminado. Recompensa: -200.0, epsilon: 0.570
# Episode 113/500 terminado. Recompensa: -200.0, epsilon: 0.568
# Episode 114/500 terminado. Recompensa: -200.0, epsilon: 0.565
# Episode 115/500 terminado. Recompensa: -200.0, epsilon: 0.562
# Episode 116/500 terminado. Recompensa: -200.0, epsilon: 0.559
# Episode 117/500 terminado. Recompensa: -200.0, epsilon: 0.556
# Episode 118/500 terminado. Recompensa: -200.0, epsilon: 0.554
# Episode 119/500 terminado. Recompensa: -200.0, epsilon: 0.551
# Episode 120/500 terminado. Recompensa: -200.0, epsilon: 0.548
# Episode 121/500 terminado. Recompensa: -200.0, epsilon: 0.545
# Episode 122/500 terminado. Recompensa: -200.0, epsilon: 0.543
# Episode 123/500 terminado. Recompensa: -200.0, epsilon: 0.540
# Episode 124/500 terminado. Recompensa: -200.0, epsilon: 0.537
# Episode 125/500 terminado. Recompensa: -200.0, epsilon: 0.534
# Episode 126/500 terminado. Recompensa: -200.0, epsilon: 0.532
# Episode 127/500 terminado. Recompensa: -200.0, epsilon: 0.529
# Episode 128/500 terminado. Recompensa: -200.0, epsilon: 0.526
# Episode 129/500 terminado. Recompensa: -200.0, epsilon: 0.524
# Episode 130/500 terminado. Recompensa: -200.0, epsilon: 0.521
# Episode 131/500 terminado. Recompensa: -200.0, epsilon: 0.519
# Episode 132/500 terminado. Recompensa: -200.0, epsilon: 0.516
# Episode 133/500 terminado. Recompensa: -200.0, epsilon: 0.513
# Episode 134/500 terminado. Recompensa: -200.0, epsilon: 0.511
# Episode 135/500 terminado. Recompensa: -200.0, epsilon: 0.508
# Episode 136/500 terminado. Recompensa: -200.0, epsilon: 0.506
# Episode 137/500 terminado. Recompensa: -200.0, epsilon: 0.503
# Episode 138/500 terminado. Recompensa: -200.0, epsilon: 0.501
# Episode 139/500 terminado. Recompensa: -200.0, epsilon: 0.498
# Episode 140/500 terminado. Recompensa: -200.0, epsilon: 0.496
# Episode 141/500 terminado. Recompensa: -200.0, epsilon: 0.493
# Episode 142/500 terminado. Recompensa: -200.0, epsilon: 0.491
# Episode 143/500 terminado. Recompensa: -200.0, epsilon: 0.488
# Episode 144/500 terminado. Recompensa: -200.0, epsilon: 0.486
# Episode 145/500 terminado. Recompensa: -200.0, epsilon: 0.483
# Episode 146/500 terminado. Recompensa: -200.0, epsilon: 0.481
# Episode 147/500 terminado. Recompensa: -200.0, epsilon: 0.479
# Episode 148/500 terminado. Recompensa: -200.0, epsilon: 0.476
# Episode 149/500 terminado. Recompensa: -200.0, epsilon: 0.474
# Episode 150/500 terminado. Recompensa: -200.0, epsilon: 0.471
# Episode 151/500 terminado. Recompensa: -200.0, epsilon: 0.469
# Episode 152/500 terminado. Recompensa: -200.0, epsilon: 0.467
# Episode 153/500 terminado. Recompensa: -200.0, epsilon: 0.464
# Episode 154/500 terminado. Recompensa: -200.0, epsilon: 0.462
# Episode 155/500 terminado. Recompensa: -200.0, epsilon: 0.460
# Episode 156/500 terminado. Recompensa: -200.0, epsilon: 0.458
# Episode 157/500 terminado. Recompensa: -200.0, epsilon: 0.455
# Episode 158/500 terminado. Recompensa: -200.0, epsilon: 0.453
# Episode 159/500 terminado. Recompensa: -200.0, epsilon: 0.451
# Episode 160/500 terminado. Recompensa: -200.0, epsilon: 0.448
# Episode 161/500 terminado. Recompensa: -200.0, epsilon: 0.446
# Episode 162/500 terminado. Recompensa: -200.0, epsilon: 0.444
# Episode 163/500 terminado. Recompensa: -200.0, epsilon: 0.442
# Episode 164/500 terminado. Recompensa: -200.0, epsilon: 0.440
# Episode 165/500 terminado. Recompensa: -200.0, epsilon: 0.437
# Episode 166/500 terminado. Recompensa: -200.0, epsilon: 0.435
# Episode 167/500 terminado. Recompensa: -200.0, epsilon: 0.433
# Episode 168/500 terminado. Recompensa: -200.0, epsilon: 0.431
# Episode 169/500 terminado. Recompensa: -200.0, epsilon: 0.429
# Episode 170/500 terminado. Recompensa: -200.0, epsilon: 0.427
# Episode 171/500 terminado. Recompensa: -200.0, epsilon: 0.424
# Episode 172/500 terminado. Recompensa: -200.0, epsilon: 0.422
# Episode 173/500 terminado. Recompensa: -200.0, epsilon: 0.420
# Episode 174/500 terminado. Recompensa: -200.0, epsilon: 0.418
# Episode 175/500 terminado. Recompensa: -200.0, epsilon: 0.416
# Episode 176/500 terminado. Recompensa: -200.0, epsilon: 0.414
# Episode 177/500 terminado. Recompensa: -200.0, epsilon: 0.412
# Episode 178/500 terminado. Recompensa: -200.0, epsilon: 0.410
# Episode 179/500 terminado. Recompensa: -200.0, epsilon: 0.408
# Episode 180/500 terminado. Recompensa: -200.0, epsilon: 0.406
# Episode 181/500 terminado. Recompensa: -200.0, epsilon: 0.404
# Episode 182/500 terminado. Recompensa: -200.0, epsilon: 0.402
# Episode 183/500 terminado. Recompensa: -200.0, epsilon: 0.400
# Episode 184/500 terminado. Recompensa: -200.0, epsilon: 0.398
# Episode 185/500 terminado. Recompensa: -200.0, epsilon: 0.396
# Episode 186/500 terminado. Recompensa: -200.0, epsilon: 0.394
# Episode 187/500 terminado. Recompensa: -200.0, epsilon: 0.392
# Episode 188/500 terminado. Recompensa: -200.0, epsilon: 0.390
# Episode 189/500 terminado. Recompensa: -200.0, epsilon: 0.388
# Episode 190/500 terminado. Recompensa: -200.0, epsilon: 0.386
# Episode 191/500 terminado. Recompensa: -200.0, epsilon: 0.384
# Episode 192/500 terminado. Recompensa: -200.0, epsilon: 0.382
# Episode 193/500 terminado. Recompensa: -200.0, epsilon: 0.380
# Episode 194/500 terminado. Recompensa: -200.0, epsilon: 0.378
# Episode 195/500 terminado. Recompensa: -200.0, epsilon: 0.376
# Episode 196/500 terminado. Recompensa: -200.0, epsilon: 0.374
# Episode 197/500 terminado. Recompensa: -200.0, epsilon: 0.373
# Episode 198/500 terminado. Recompensa: -200.0, epsilon: 0.371
# Episode 199/500 terminado. Recompensa: -200.0, epsilon: 0.369
# Episode 200/500 terminado. Recompensa: -200.0, epsilon: 0.367
# Episode 201/500 terminado. Recompensa: -200.0, epsilon: 0.365
# Episode 202/500 terminado. Recompensa: -200.0, epsilon: 0.363
# Episode 203/500 terminado. Recompensa: -200.0, epsilon: 0.361
# Episode 204/500 terminado. Recompensa: -200.0, epsilon: 0.360
# Episode 205/500 terminado. Recompensa: -200.0, epsilon: 0.358
# Episode 206/500 terminado. Recompensa: -200.0, epsilon: 0.356
# Episode 207/500 terminado. Recompensa: -200.0, epsilon: 0.354
# Episode 208/500 terminado. Recompensa: -200.0, epsilon: 0.353
# Episode 209/500 terminado. Recompensa: -200.0, epsilon: 0.351
# Episode 210/500 terminado. Recompensa: -200.0, epsilon: 0.349
# Episode 211/500 terminado. Recompensa: -200.0, epsilon: 0.347
# Episode 212/500 terminado. Recompensa: -200.0, epsilon: 0.346
# Episode 213/500 terminado. Recompensa: -200.0, epsilon: 0.344
# Episode 214/500 terminado. Recompensa: -200.0, epsilon: 0.342
# Episode 215/500 terminado. Recompensa: -200.0, epsilon: 0.340
# Episode 216/500 terminado. Recompensa: -200.0, epsilon: 0.339
# Episode 217/500 terminado. Recompensa: -200.0, epsilon: 0.337
# Episode 218/500 terminado. Recompensa: -200.0, epsilon: 0.335
# Episode 219/500 terminado. Recompensa: -200.0, epsilon: 0.334
# Episode 220/500 terminado. Recompensa: -200.0, epsilon: 0.332
# Episode 221/500 terminado. Recompensa: -200.0, epsilon: 0.330
# Episode 222/500 terminado. Recompensa: -200.0, epsilon: 0.329
# Episode 223/500 terminado. Recompensa: -200.0, epsilon: 0.327
# Episode 224/500 terminado. Recompensa: -200.0, epsilon: 0.325
# Episode 225/500 terminado. Recompensa: -200.0, epsilon: 0.324
# Episode 226/500 terminado. Recompensa: -200.0, epsilon: 0.322
# Episode 227/500 terminado. Recompensa: -200.0, epsilon: 0.321
# Episode 228/500 terminado. Recompensa: -200.0, epsilon: 0.319
# Episode 229/500 terminado. Recompensa: -200.0, epsilon: 0.317
# Episode 230/500 terminado. Recompensa: -200.0, epsilon: 0.316
# Episode 231/500 terminado. Recompensa: -200.0, epsilon: 0.314
# Episode 232/500 terminado. Recompensa: -200.0, epsilon: 0.313
# Episode 233/500 terminado. Recompensa: -200.0, epsilon: 0.311
# Episode 234/500 terminado. Recompensa: -200.0, epsilon: 0.309
# Episode 235/500 terminado. Recompensa: -200.0, epsilon: 0.308
# Episode 236/500 terminado. Recompensa: -200.0, epsilon: 0.306
# Episode 237/500 terminado. Recompensa: -200.0, epsilon: 0.305
# Episode 238/500 terminado. Recompensa: -200.0, epsilon: 0.303
# Episode 239/500 terminado. Recompensa: -200.0, epsilon: 0.302
# Episode 240/500 terminado. Recompensa: -200.0, epsilon: 0.300
# Episode 241/500 terminado. Recompensa: -200.0, epsilon: 0.299
# Episode 242/500 terminado. Recompensa: -200.0, epsilon: 0.297
# Episode 243/500 terminado. Recompensa: -200.0, epsilon: 0.296
# Episode 244/500 terminado. Recompensa: -200.0, epsilon: 0.294
# Episode 245/500 terminado. Recompensa: -200.0, epsilon: 0.293
# Episode 246/500 terminado. Recompensa: -200.0, epsilon: 0.291
# Episode 247/500 terminado. Recompensa: -200.0, epsilon: 0.290
# Episode 248/500 terminado. Recompensa: -200.0, epsilon: 0.288
# Episode 249/500 terminado. Recompensa: -200.0, epsilon: 0.287
# Episode 250/500 terminado. Recompensa: -200.0, epsilon: 0.286
# Episode 251/500 terminado. Recompensa: -200.0, epsilon: 0.284
# Episode 252/500 terminado. Recompensa: -200.0, epsilon: 0.283
# Episode 253/500 terminado. Recompensa: -200.0, epsilon: 0.281
# Episode 254/500 terminado. Recompensa: -200.0, epsilon: 0.280
# Episode 255/500 terminado. Recompensa: -200.0, epsilon: 0.279
# Episode 256/500 terminado. Recompensa: -200.0, epsilon: 0.277
# Episode 257/500 terminado. Recompensa: -200.0, epsilon: 0.276
# Episode 258/500 terminado. Recompensa: -200.0, epsilon: 0.274
# Episode 259/500 terminado. Recompensa: -200.0, epsilon: 0.273
# Episode 260/500 terminado. Recompensa: -200.0, epsilon: 0.272
# Episode 261/500 terminado. Recompensa: -200.0, epsilon: 0.270
# Episode 262/500 terminado. Recompensa: -200.0, epsilon: 0.269
# Episode 263/500 terminado. Recompensa: -200.0, epsilon: 0.268
# Episode 264/500 terminado. Recompensa: -200.0, epsilon: 0.266
# Episode 265/500 terminado. Recompensa: -200.0, epsilon: 0.265
# Episode 266/500 terminado. Recompensa: -200.0, epsilon: 0.264
# Episode 267/500 terminado. Recompensa: -200.0, epsilon: 0.262
# Episode 268/500 terminado. Recompensa: -200.0, epsilon: 0.261
# Episode 269/500 terminado. Recompensa: -200.0, epsilon: 0.260
# Episode 270/500 terminado. Recompensa: -200.0, epsilon: 0.258
# Episode 271/500 terminado. Recompensa: -200.0, epsilon: 0.257
# Episode 272/500 terminado. Recompensa: -200.0, epsilon: 0.256
# Episode 273/500 terminado. Recompensa: -200.0, epsilon: 0.255
# Episode 274/500 terminado. Recompensa: -200.0, epsilon: 0.253
# Episode 275/500 terminado. Recompensa: -200.0, epsilon: 0.252
# Episode 276/500 terminado. Recompensa: -200.0, epsilon: 0.251
# Episode 277/500 terminado. Recompensa: -200.0, epsilon: 0.249
# Episode 278/500 terminado. Recompensa: -200.0, epsilon: 0.248
# Episode 279/500 terminado. Recompensa: -200.0, epsilon: 0.247
# Episode 280/500 terminado. Recompensa: -200.0, epsilon: 0.246
# Episode 281/500 terminado. Recompensa: -200.0, epsilon: 0.245
# Episode 282/500 terminado. Recompensa: -200.0, epsilon: 0.243
# Episode 283/500 terminado. Recompensa: -200.0, epsilon: 0.242
# Episode 284/500 terminado. Recompensa: -200.0, epsilon: 0.241
# Episode 285/500 terminado. Recompensa: -200.0, epsilon: 0.240
# Episode 286/500 terminado. Recompensa: -200.0, epsilon: 0.238
# Episode 287/500 terminado. Recompensa: -200.0, epsilon: 0.237
# Episode 288/500 terminado. Recompensa: -200.0, epsilon: 0.236
# Episode 289/500 terminado. Recompensa: -200.0, epsilon: 0.235
# Episode 290/500 terminado. Recompensa: -200.0, epsilon: 0.234
# Episode 291/500 terminado. Recompensa: -200.0, epsilon: 0.233
# Episode 292/500 terminado. Recompensa: -200.0, epsilon: 0.231
# Episode 293/500 terminado. Recompensa: -200.0, epsilon: 0.230
# Episode 294/500 terminado. Recompensa: -200.0, epsilon: 0.229
# Episode 295/500 terminado. Recompensa: -200.0, epsilon: 0.228
# Episode 296/500 terminado. Recompensa: -200.0, epsilon: 0.227
# Episode 297/500 terminado. Recompensa: -200.0, epsilon: 0.226
# Episode 298/500 terminado. Recompensa: -200.0, epsilon: 0.225
# Episode 299/500 terminado. Recompensa: -200.0, epsilon: 0.223
# Episode 300/500 terminado. Recompensa: -200.0, epsilon: 0.222
# Episode 301/500 terminado. Recompensa: -200.0, epsilon: 0.221
# Episode 302/500 terminado. Recompensa: -200.0, epsilon: 0.220
# Episode 303/500 terminado. Recompensa: -200.0, epsilon: 0.219
# Episode 304/500 terminado. Recompensa: -200.0, epsilon: 0.218
# Episode 305/500 terminado. Recompensa: -200.0, epsilon: 0.217
# Episode 306/500 terminado. Recompensa: -200.0, epsilon: 0.216
# Episode 307/500 terminado. Recompensa: -200.0, epsilon: 0.215
# Episode 308/500 terminado. Recompensa: -200.0, epsilon: 0.214
# Episode 309/500 terminado. Recompensa: -200.0, epsilon: 0.212
# Episode 310/500 terminado. Recompensa: -200.0, epsilon: 0.211
# Episode 311/500 terminado. Recompensa: -200.0, epsilon: 0.210
# Episode 312/500 terminado. Recompensa: -200.0, epsilon: 0.209
# Episode 313/500 terminado. Recompensa: -200.0, epsilon: 0.208
# Episode 314/500 terminado. Recompensa: -200.0, epsilon: 0.207
# Episode 315/500 terminado. Recompensa: -200.0, epsilon: 0.206
# Episode 316/500 terminado. Recompensa: -200.0, epsilon: 0.205
# Episode 317/500 terminado. Recompensa: -200.0, epsilon: 0.204
# Episode 318/500 terminado. Recompensa: -200.0, epsilon: 0.203
# Episode 319/500 terminado. Recompensa: -200.0, epsilon: 0.202
# Episode 320/500 terminado. Recompensa: -200.0, epsilon: 0.201
# Episode 321/500 terminado. Recompensa: -200.0, epsilon: 0.200
# Episode 322/500 terminado. Recompensa: -200.0, epsilon: 0.199
# Episode 323/500 terminado. Recompensa: -200.0, epsilon: 0.198
# Episode 324/500 terminado. Recompensa: -200.0, epsilon: 0.197
# Episode 325/500 terminado. Recompensa: -200.0, epsilon: 0.196
# Episode 326/500 terminado. Recompensa: -200.0, epsilon: 0.195
# Episode 327/500 terminado. Recompensa: -200.0, epsilon: 0.194
# Episode 328/500 terminado. Recompensa: -200.0, epsilon: 0.193
# Episode 329/500 terminado. Recompensa: -200.0, epsilon: 0.192
# Episode 330/500 terminado. Recompensa: -200.0, epsilon: 0.191
# Episode 331/500 terminado. Recompensa: -200.0, epsilon: 0.190
# Episode 332/500 terminado. Recompensa: -200.0, epsilon: 0.189
# Episode 333/500 terminado. Recompensa: -200.0, epsilon: 0.188
# Episode 334/500 terminado. Recompensa: -200.0, epsilon: 0.187
# Episode 335/500 terminado. Recompensa: -200.0, epsilon: 0.187
# Episode 336/500 terminado. Recompensa: -200.0, epsilon: 0.186
# Episode 337/500 terminado. Recompensa: -200.0, epsilon: 0.185
# Episode 338/500 terminado. Recompensa: -200.0, epsilon: 0.184
# Episode 339/500 terminado. Recompensa: -200.0, epsilon: 0.183
# Episode 340/500 terminado. Recompensa: -200.0, epsilon: 0.182
# Episode 341/500 terminado. Recompensa: -200.0, epsilon: 0.181
# Episode 342/500 terminado. Recompensa: -200.0, epsilon: 0.180
# Episode 343/500 terminado. Recompensa: -200.0, epsilon: 0.179
# Episode 344/500 terminado. Recompensa: -200.0, epsilon: 0.178
# Episode 345/500 terminado. Recompensa: -200.0, epsilon: 0.177
# Episode 346/500 terminado. Recompensa: -200.0, epsilon: 0.177
# Episode 347/500 terminado. Recompensa: -200.0, epsilon: 0.176
# Episode 348/500 terminado. Recompensa: -200.0, epsilon: 0.175
# Episode 349/500 terminado. Recompensa: -200.0, epsilon: 0.174
# Episode 350/500 terminado. Recompensa: -200.0, epsilon: 0.173
# Episode 351/500 terminado. Recompensa: -200.0, epsilon: 0.172
# Episode 352/500 terminado. Recompensa: -200.0, epsilon: 0.171
# Episode 353/500 terminado. Recompensa: -200.0, epsilon: 0.170
# Episode 354/500 terminado. Recompensa: -200.0, epsilon: 0.170
# Episode 355/500 terminado. Recompensa: -200.0, epsilon: 0.169
# Episode 356/500 terminado. Recompensa: -200.0, epsilon: 0.168
# Episode 357/500 terminado. Recompensa: -200.0, epsilon: 0.167
# Episode 358/500 terminado. Recompensa: -200.0, epsilon: 0.166
# Episode 359/500 terminado. Recompensa: -200.0, epsilon: 0.165
# Episode 360/500 terminado. Recompensa: -200.0, epsilon: 0.165
# Episode 361/500 terminado. Recompensa: -200.0, epsilon: 0.164
# Episode 362/500 terminado. Recompensa: -200.0, epsilon: 0.163
# Episode 363/500 terminado. Recompensa: -200.0, epsilon: 0.162
# Episode 364/500 terminado. Recompensa: -200.0, epsilon: 0.161
# Episode 365/500 terminado. Recompensa: -200.0, epsilon: 0.160
# Episode 366/500 terminado. Recompensa: -200.0, epsilon: 0.160
# Episode 367/500 terminado. Recompensa: -200.0, epsilon: 0.159
# Episode 368/500 terminado. Recompensa: -200.0, epsilon: 0.158
# Episode 369/500 terminado. Recompensa: -200.0, epsilon: 0.157
# Episode 370/500 terminado. Recompensa: -200.0, epsilon: 0.157
# Episode 371/500 terminado. Recompensa: -200.0, epsilon: 0.156
# Episode 372/500 terminado. Recompensa: -200.0, epsilon: 0.155
# Episode 373/500 terminado. Recompensa: -200.0, epsilon: 0.154
# Episode 374/500 terminado. Recompensa: -200.0, epsilon: 0.153
# Episode 375/500 terminado. Recompensa: -200.0, epsilon: 0.153
# Episode 376/500 terminado. Recompensa: -200.0, epsilon: 0.152
# Episode 377/500 terminado. Recompensa: -200.0, epsilon: 0.151
# Episode 378/500 terminado. Recompensa: -200.0, epsilon: 0.150
# Episode 379/500 terminado. Recompensa: -200.0, epsilon: 0.150
# Episode 380/500 terminado. Recompensa: -200.0, epsilon: 0.149
# Episode 381/500 terminado. Recompensa: -200.0, epsilon: 0.148
# Episode 382/500 terminado. Recompensa: -200.0, epsilon: 0.147
# Episode 383/500 terminado. Recompensa: -200.0, epsilon: 0.147
# Episode 384/500 terminado. Recompensa: -200.0, epsilon: 0.146
# Episode 385/500 terminado. Recompensa: -200.0, epsilon: 0.145
# Episode 386/500 terminado. Recompensa: -200.0, epsilon: 0.144
# Episode 387/500 terminado. Recompensa: -200.0, epsilon: 0.144
# Episode 388/500 terminado. Recompensa: -200.0, epsilon: 0.143
# Episode 389/500 terminado. Recompensa: -200.0, epsilon: 0.142
# Episode 390/500 terminado. Recompensa: -200.0, epsilon: 0.142
# Episode 391/500 terminado. Recompensa: -200.0, epsilon: 0.141
# Episode 392/500 terminado. Recompensa: -200.0, epsilon: 0.140
# Episode 393/500 terminado. Recompensa: -200.0, epsilon: 0.139
# Episode 394/500 terminado. Recompensa: -200.0, epsilon: 0.139
# Episode 395/500 terminado. Recompensa: -200.0, epsilon: 0.138
# Episode 396/500 terminado. Recompensa: -200.0, epsilon: 0.137
# Episode 397/500 terminado. Recompensa: -200.0, epsilon: 0.137
# Episode 398/500 terminado. Recompensa: -200.0, epsilon: 0.136
# Episode 399/500 terminado. Recompensa: -200.0, epsilon: 0.135
# Episode 400/500 terminado. Recompensa: -200.0, epsilon: 0.135
# Episode 401/500 terminado. Recompensa: -200.0, epsilon: 0.134
# Episode 402/500 terminado. Recompensa: -200.0, epsilon: 0.133
# Episode 403/500 terminado. Recompensa: -200.0, epsilon: 0.133
# Episode 404/500 terminado. Recompensa: -200.0, epsilon: 0.132
# Episode 405/500 terminado. Recompensa: -200.0, epsilon: 0.131
# Episode 406/500 terminado. Recompensa: -200.0, epsilon: 0.131
# Episode 407/500 terminado. Recompensa: -200.0, epsilon: 0.130
# Episode 408/500 terminado. Recompensa: -200.0, epsilon: 0.129
# Episode 409/500 terminado. Recompensa: -200.0, epsilon: 0.129
# Episode 410/500 terminado. Recompensa: -200.0, epsilon: 0.128
# Episode 411/500 terminado. Recompensa: -200.0, epsilon: 0.127
# Episode 412/500 terminado. Recompensa: -200.0, epsilon: 0.127
# Episode 413/500 terminado. Recompensa: -200.0, epsilon: 0.126
# Episode 414/500 terminado. Recompensa: -200.0, epsilon: 0.126
# Episode 415/500 terminado. Recompensa: -200.0, epsilon: 0.125
# Episode 416/500 terminado. Recompensa: -200.0, epsilon: 0.124
# Episode 417/500 terminado. Recompensa: -200.0, epsilon: 0.124
# Episode 418/500 terminado. Recompensa: -200.0, epsilon: 0.123
# Episode 419/500 terminado. Recompensa: -200.0, epsilon: 0.122
# Episode 420/500 terminado. Recompensa: -200.0, epsilon: 0.122
# Episode 421/500 terminado. Recompensa: -200.0, epsilon: 0.121
# Episode 422/500 terminado. Recompensa: -200.0, epsilon: 0.121
# Episode 423/500 terminado. Recompensa: -200.0, epsilon: 0.120
# Episode 424/500 terminado. Recompensa: -200.0, epsilon: 0.119
# Episode 425/500 terminado. Recompensa: -200.0, epsilon: 0.119
# Episode 426/500 terminado. Recompensa: -200.0, epsilon: 0.118
# Episode 427/500 terminado. Recompensa: -200.0, epsilon: 0.118
# Episode 428/500 terminado. Recompensa: -200.0, epsilon: 0.117
# Episode 429/500 terminado. Recompensa: -200.0, epsilon: 0.116
# Episode 430/500 terminado. Recompensa: -200.0, epsilon: 0.116
# Episode 431/500 terminado. Recompensa: -200.0, epsilon: 0.115
# Episode 432/500 terminado. Recompensa: -200.0, epsilon: 0.115
# Episode 433/500 terminado. Recompensa: -200.0, epsilon: 0.114
# Episode 434/500 terminado. Recompensa: -200.0, epsilon: 0.114
# Episode 435/500 terminado. Recompensa: -200.0, epsilon: 0.113
# Episode 436/500 terminado. Recompensa: -200.0, epsilon: 0.112
# Episode 437/500 terminado. Recompensa: -200.0, epsilon: 0.112
# Episode 438/500 terminado. Recompensa: -200.0, epsilon: 0.111
# Episode 439/500 terminado. Recompensa: -200.0, epsilon: 0.111
# Episode 440/500 terminado. Recompensa: -200.0, epsilon: 0.110
# Episode 441/500 terminado. Recompensa: -200.0, epsilon: 0.110
# Episode 442/500 terminado. Recompensa: -200.0, epsilon: 0.109
# Episode 443/500 terminado. Recompensa: -200.0, epsilon: 0.109
# Episode 444/500 terminado. Recompensa: -200.0, epsilon: 0.108
# Episode 445/500 terminado. Recompensa: -200.0, epsilon: 0.107
# Episode 446/500 terminado. Recompensa: -200.0, epsilon: 0.107
# Episode 447/500 terminado. Recompensa: -200.0, epsilon: 0.106
# Episode 448/500 terminado. Recompensa: -200.0, epsilon: 0.106
# Episode 449/500 terminado. Recompensa: -200.0, epsilon: 0.105
# Episode 450/500 terminado. Recompensa: -200.0, epsilon: 0.105
# Episode 451/500 terminado. Recompensa: -200.0, epsilon: 0.104
# Episode 452/500 terminado. Recompensa: -200.0, epsilon: 0.104
# Episode 453/500 terminado. Recompensa: -200.0, epsilon: 0.103
# Episode 454/500 terminado. Recompensa: -200.0, epsilon: 0.103
# Episode 455/500 terminado. Recompensa: -200.0, epsilon: 0.102
# Episode 456/500 terminado. Recompensa: -200.0, epsilon: 0.102
# Episode 457/500 terminado. Recompensa: -200.0, epsilon: 0.101
# Episode 458/500 terminado. Recompensa: -200.0, epsilon: 0.101
# Episode 459/500 terminado. Recompensa: -200.0, epsilon: 0.100
# Episode 460/500 terminado. Recompensa: -200.0, epsilon: 0.100
# Episode 461/500 terminado. Recompensa: -200.0, epsilon: 0.099
# Episode 462/500 terminado. Recompensa: -200.0, epsilon: 0.099
# Episode 463/500 terminado. Recompensa: -200.0, epsilon: 0.098
# Episode 464/500 terminado. Recompensa: -200.0, epsilon: 0.098
# Episode 465/500 terminado. Recompensa: -200.0, epsilon: 0.097
# Episode 466/500 terminado. Recompensa: -200.0, epsilon: 0.097
# Episode 467/500 terminado. Recompensa: -200.0, epsilon: 0.096
# Episode 468/500 terminado. Recompensa: -200.0, epsilon: 0.096
# Episode 469/500 terminado. Recompensa: -200.0, epsilon: 0.095
# Episode 470/500 terminado. Recompensa: -200.0, epsilon: 0.095
# Episode 471/500 terminado. Recompensa: -200.0, epsilon: 0.094
# Episode 472/500 terminado. Recompensa: -200.0, epsilon: 0.094
# Episode 473/500 terminado. Recompensa: -200.0, epsilon: 0.093
# Episode 474/500 terminado. Recompensa: -200.0, epsilon: 0.093
# Episode 475/500 terminado. Recompensa: -200.0, epsilon: 0.092
# Episode 476/500 terminado. Recompensa: -200.0, epsilon: 0.092
# Episode 477/500 terminado. Recompensa: -200.0, epsilon: 0.092
# Episode 478/500 terminado. Recompensa: -200.0, epsilon: 0.091
# Episode 479/500 terminado. Recompensa: -200.0, epsilon: 0.091
# Episode 480/500 terminado. Recompensa: -200.0, epsilon: 0.090
# Episode 481/500 terminado. Recompensa: -200.0, epsilon: 0.090
# Episode 482/500 terminado. Recompensa: -200.0, epsilon: 0.089
# Episode 483/500 terminado. Recompensa: -200.0, epsilon: 0.089
# Episode 484/500 terminado. Recompensa: -200.0, epsilon: 0.088
# Episode 485/500 terminado. Recompensa: -200.0, epsilon: 0.088
# Episode 486/500 terminado. Recompensa: -200.0, epsilon: 0.088
# Episode 487/500 terminado. Recompensa: -200.0, epsilon: 0.087
# Episode 488/500 terminado. Recompensa: -200.0, epsilon: 0.087
# Episode 489/500 terminado. Recompensa: -200.0, epsilon: 0.086
# Episode 490/500 terminado. Recompensa: -200.0, epsilon: 0.086
# Episode 491/500 terminado. Recompensa: -200.0, epsilon: 0.085
# Episode 492/500 terminado. Recompensa: -200.0, epsilon: 0.085
# Episode 493/500 terminado. Recompensa: -200.0, epsilon: 0.084
# Episode 494/500 terminado. Recompensa: -200.0, epsilon: 0.084
# Episode 495/500 terminado. Recompensa: -200.0, epsilon: 0.084
# Episode 496/500 terminado. Recompensa: -200.0, epsilon: 0.083
# Episode 497/500 terminado. Recompensa: -200.0, epsilon: 0.083
# Episode 498/500 terminado. Recompensa: -200.0, epsilon: 0.082
# Episode 499/500 terminado. Recompensa: -200.0, epsilon: 0.082
# Episode 500/500 terminado. Recompensa: -200.0, epsilon: 0.082
#
# === Experimento 2 ===
# Episode 1/500 terminado. Recompensa: -200.0, epsilon: 0.995
# Episode 2/500 terminado. Recompensa: -200.0, epsilon: 0.990
# Episode 3/500 terminado. Recompensa: -200.0, epsilon: 0.985
# Episode 4/500 terminado. Recompensa: -200.0, epsilon: 0.980
# Episode 5/500 terminado. Recompensa: -200.0, epsilon: 0.975
# Episode 6/500 terminado. Recompensa: -200.0, epsilon: 0.970
# Episode 7/500 terminado. Recompensa: -200.0, epsilon: 0.966
# Episode 8/500 terminado. Recompensa: -200.0, epsilon: 0.961
# Episode 9/500 terminado. Recompensa: -200.0, epsilon: 0.956
# Episode 10/500 terminado. Recompensa: -200.0, epsilon: 0.951
# Episode 11/500 terminado. Recompensa: -200.0, epsilon: 0.946
# Episode 12/500 terminado. Recompensa: -200.0, epsilon: 0.942
# Episode 13/500 terminado. Recompensa: -200.0, epsilon: 0.937
# Episode 14/500 terminado. Recompensa: -200.0, epsilon: 0.932
# Episode 15/500 terminado. Recompensa: -200.0, epsilon: 0.928
# Episode 16/500 terminado. Recompensa: -200.0, epsilon: 0.923
# Episode 17/500 terminado. Recompensa: -200.0, epsilon: 0.918
# Episode 18/500 terminado. Recompensa: -200.0, epsilon: 0.914
# Episode 19/500 terminado. Recompensa: -200.0, epsilon: 0.909
# Episode 20/500 terminado. Recompensa: -200.0, epsilon: 0.905
# Episode 21/500 terminado. Recompensa: -200.0, epsilon: 0.900
# Episode 22/500 terminado. Recompensa: -200.0, epsilon: 0.896
# Episode 23/500 terminado. Recompensa: -200.0, epsilon: 0.891
# Episode 24/500 terminado. Recompensa: -200.0, epsilon: 0.887
# Episode 25/500 terminado. Recompensa: -200.0, epsilon: 0.882
# Episode 26/500 terminado. Recompensa: -200.0, epsilon: 0.878
# Episode 27/500 terminado. Recompensa: -200.0, epsilon: 0.873
# Episode 28/500 terminado. Recompensa: -200.0, epsilon: 0.869
# Episode 29/500 terminado. Recompensa: -200.0, epsilon: 0.865
# Episode 30/500 terminado. Recompensa: -200.0, epsilon: 0.860
# Episode 31/500 terminado. Recompensa: -200.0, epsilon: 0.856
# Episode 32/500 terminado. Recompensa: -200.0, epsilon: 0.852
# Episode 33/500 terminado. Recompensa: -200.0, epsilon: 0.848
# Episode 34/500 terminado. Recompensa: -200.0, epsilon: 0.843
# Episode 35/500 terminado. Recompensa: -200.0, epsilon: 0.839
# Episode 36/500 terminado. Recompensa: -200.0, epsilon: 0.835
# Episode 37/500 terminado. Recompensa: -200.0, epsilon: 0.831
# Episode 38/500 terminado. Recompensa: -200.0, epsilon: 0.827
# Episode 39/500 terminado. Recompensa: -200.0, epsilon: 0.822
# Episode 40/500 terminado. Recompensa: -200.0, epsilon: 0.818
# Episode 41/500 terminado. Recompensa: -200.0, epsilon: 0.814
# Episode 42/500 terminado. Recompensa: -200.0, epsilon: 0.810
# Episode 43/500 terminado. Recompensa: -200.0, epsilon: 0.806
# Episode 44/500 terminado. Recompensa: -200.0, epsilon: 0.802
# Episode 45/500 terminado. Recompensa: -200.0, epsilon: 0.798
# Episode 46/500 terminado. Recompensa: -200.0, epsilon: 0.794
# Episode 47/500 terminado. Recompensa: -200.0, epsilon: 0.790
# Episode 48/500 terminado. Recompensa: -200.0, epsilon: 0.786
# Episode 49/500 terminado. Recompensa: -200.0, epsilon: 0.782
# Episode 50/500 terminado. Recompensa: -200.0, epsilon: 0.778
# Episode 51/500 terminado. Recompensa: -200.0, epsilon: 0.774
# Episode 52/500 terminado. Recompensa: -200.0, epsilon: 0.771
# Episode 53/500 terminado. Recompensa: -200.0, epsilon: 0.767
# Episode 54/500 terminado. Recompensa: -200.0, epsilon: 0.763
# Episode 55/500 terminado. Recompensa: -200.0, epsilon: 0.759
# Episode 56/500 terminado. Recompensa: -200.0, epsilon: 0.755
# Episode 57/500 terminado. Recompensa: -200.0, epsilon: 0.751
# Episode 58/500 terminado. Recompensa: -200.0, epsilon: 0.748
# Episode 59/500 terminado. Recompensa: -200.0, epsilon: 0.744
# Episode 60/500 terminado. Recompensa: -200.0, epsilon: 0.740
# Episode 61/500 terminado. Recompensa: -200.0, epsilon: 0.737
# Episode 62/500 terminado. Recompensa: -200.0, epsilon: 0.733
# Episode 63/500 terminado. Recompensa: -200.0, epsilon: 0.729
# Episode 64/500 terminado. Recompensa: -200.0, epsilon: 0.726
# Episode 65/500 terminado. Recompensa: -200.0, epsilon: 0.722
# Episode 66/500 terminado. Recompensa: -200.0, epsilon: 0.718
# Episode 67/500 terminado. Recompensa: -200.0, epsilon: 0.715
# Episode 68/500 terminado. Recompensa: -200.0, epsilon: 0.711
# Episode 69/500 terminado. Recompensa: -200.0, epsilon: 0.708
# Episode 70/500 terminado. Recompensa: -200.0, epsilon: 0.704
# Episode 71/500 terminado. Recompensa: -200.0, epsilon: 0.701
# Episode 72/500 terminado. Recompensa: -200.0, epsilon: 0.697
# Episode 73/500 terminado. Recompensa: -200.0, epsilon: 0.694
# Episode 74/500 terminado. Recompensa: -200.0, epsilon: 0.690
# Episode 75/500 terminado. Recompensa: -200.0, epsilon: 0.687
# Episode 76/500 terminado. Recompensa: -200.0, epsilon: 0.683
# Episode 77/500 terminado. Recompensa: -200.0, epsilon: 0.680
# Episode 78/500 terminado. Recompensa: -200.0, epsilon: 0.676
# Episode 79/500 terminado. Recompensa: -200.0, epsilon: 0.673
# Episode 80/500 terminado. Recompensa: -200.0, epsilon: 0.670
# Episode 81/500 terminado. Recompensa: -200.0, epsilon: 0.666
# Episode 82/500 terminado. Recompensa: -200.0, epsilon: 0.663
# Episode 83/500 terminado. Recompensa: -200.0, epsilon: 0.660
# Episode 84/500 terminado. Recompensa: -200.0, epsilon: 0.656
# Episode 85/500 terminado. Recompensa: -200.0, epsilon: 0.653
# Episode 86/500 terminado. Recompensa: -200.0, epsilon: 0.650
# Episode 87/500 terminado. Recompensa: -200.0, epsilon: 0.647
# Episode 88/500 terminado. Recompensa: -200.0, epsilon: 0.643
# Episode 89/500 terminado. Recompensa: -200.0, epsilon: 0.640
# Episode 90/500 terminado. Recompensa: -200.0, epsilon: 0.637
# Episode 91/500 terminado. Recompensa: -200.0, epsilon: 0.634
# Episode 92/500 terminado. Recompensa: -200.0, epsilon: 0.631
# Episode 93/500 terminado. Recompensa: -200.0, epsilon: 0.627
# Episode 94/500 terminado. Recompensa: -200.0, epsilon: 0.624
# Episode 95/500 terminado. Recompensa: -200.0, epsilon: 0.621
# Episode 96/500 terminado. Recompensa: -200.0, epsilon: 0.618
# Episode 97/500 terminado. Recompensa: -200.0, epsilon: 0.615
# Episode 98/500 terminado. Recompensa: -200.0, epsilon: 0.612
# Episode 99/500 terminado. Recompensa: -200.0, epsilon: 0.609
# Episode 100/500 terminado. Recompensa: -200.0, epsilon: 0.606
# Episode 101/500 terminado. Recompensa: -200.0, epsilon: 0.603
# Episode 102/500 terminado. Recompensa: -200.0, epsilon: 0.600
# Episode 103/500 terminado. Recompensa: -200.0, epsilon: 0.597
# Episode 104/500 terminado. Recompensa: -200.0, epsilon: 0.594
# Episode 105/500 terminado. Recompensa: -200.0, epsilon: 0.591
# Episode 106/500 terminado. Recompensa: -200.0, epsilon: 0.588
# Episode 107/500 terminado. Recompensa: -200.0, epsilon: 0.585
# Episode 108/500 terminado. Recompensa: -200.0, epsilon: 0.582
# Episode 109/500 terminado. Recompensa: -200.0, epsilon: 0.579
# Episode 110/500 terminado. Recompensa: -200.0, epsilon: 0.576
# Episode 111/500 terminado. Recompensa: -200.0, epsilon: 0.573
# Episode 112/500 terminado. Recompensa: -200.0, epsilon: 0.570
# Episode 113/500 terminado. Recompensa: -200.0, epsilon: 0.568
# Episode 114/500 terminado. Recompensa: -200.0, epsilon: 0.565
# Episode 115/500 terminado. Recompensa: -200.0, epsilon: 0.562
# Episode 116/500 terminado. Recompensa: -200.0, epsilon: 0.559
# Episode 117/500 terminado. Recompensa: -200.0, epsilon: 0.556
# Episode 118/500 terminado. Recompensa: -200.0, epsilon: 0.554
# Episode 119/500 terminado. Recompensa: -200.0, epsilon: 0.551
# Episode 120/500 terminado. Recompensa: -200.0, epsilon: 0.548
# Episode 121/500 terminado. Recompensa: -200.0, epsilon: 0.545
# Episode 122/500 terminado. Recompensa: -200.0, epsilon: 0.543
# Episode 123/500 terminado. Recompensa: -200.0, epsilon: 0.540
# Episode 124/500 terminado. Recompensa: -200.0, epsilon: 0.537
# Episode 125/500 terminado. Recompensa: -200.0, epsilon: 0.534
# Episode 126/500 terminado. Recompensa: -200.0, epsilon: 0.532
# Episode 127/500 terminado. Recompensa: -200.0, epsilon: 0.529
# Episode 128/500 terminado. Recompensa: -200.0, epsilon: 0.526
# Episode 129/500 terminado. Recompensa: -200.0, epsilon: 0.524
# Episode 130/500 terminado. Recompensa: -200.0, epsilon: 0.521
# Episode 131/500 terminado. Recompensa: -200.0, epsilon: 0.519
# Episode 132/500 terminado. Recompensa: -200.0, epsilon: 0.516
# Episode 133/500 terminado. Recompensa: -200.0, epsilon: 0.513
# Episode 134/500 terminado. Recompensa: -200.0, epsilon: 0.511
# Episode 135/500 terminado. Recompensa: -200.0, epsilon: 0.508
# Episode 136/500 terminado. Recompensa: -200.0, epsilon: 0.506
# Episode 137/500 terminado. Recompensa: -200.0, epsilon: 0.503
# Episode 138/500 terminado. Recompensa: -200.0, epsilon: 0.501
# Episode 139/500 terminado. Recompensa: -200.0, epsilon: 0.498
# Episode 140/500 terminado. Recompensa: -200.0, epsilon: 0.496
# Episode 141/500 terminado. Recompensa: -200.0, epsilon: 0.493
# Episode 142/500 terminado. Recompensa: -200.0, epsilon: 0.491
# Episode 143/500 terminado. Recompensa: -200.0, epsilon: 0.488
# Episode 144/500 terminado. Recompensa: -200.0, epsilon: 0.486
# Episode 145/500 terminado. Recompensa: -200.0, epsilon: 0.483
# Episode 146/500 terminado. Recompensa: -200.0, epsilon: 0.481
# Episode 147/500 terminado. Recompensa: -200.0, epsilon: 0.479
# Episode 148/500 terminado. Recompensa: -200.0, epsilon: 0.476
# Episode 149/500 terminado. Recompensa: -200.0, epsilon: 0.474
# Episode 150/500 terminado. Recompensa: -200.0, epsilon: 0.471
# Episode 151/500 terminado. Recompensa: -200.0, epsilon: 0.469
# Episode 152/500 terminado. Recompensa: -200.0, epsilon: 0.467
# Episode 153/500 terminado. Recompensa: -200.0, epsilon: 0.464
# Episode 154/500 terminado. Recompensa: -200.0, epsilon: 0.462
# Episode 155/500 terminado. Recompensa: -200.0, epsilon: 0.460
# Episode 156/500 terminado. Recompensa: -200.0, epsilon: 0.458
# Episode 157/500 terminado. Recompensa: -200.0, epsilon: 0.455
# Episode 158/500 terminado. Recompensa: -200.0, epsilon: 0.453
# Episode 159/500 terminado. Recompensa: -200.0, epsilon: 0.451
# Episode 160/500 terminado. Recompensa: -200.0, epsilon: 0.448
# Episode 161/500 terminado. Recompensa: -200.0, epsilon: 0.446
# Episode 162/500 terminado. Recompensa: -200.0, epsilon: 0.444
# Episode 163/500 terminado. Recompensa: -200.0, epsilon: 0.442
# Episode 164/500 terminado. Recompensa: -200.0, epsilon: 0.440
# Episode 165/500 terminado. Recompensa: -200.0, epsilon: 0.437
# Episode 166/500 terminado. Recompensa: -200.0, epsilon: 0.435
# Episode 167/500 terminado. Recompensa: -200.0, epsilon: 0.433
# Episode 168/500 terminado. Recompensa: -200.0, epsilon: 0.431
# Episode 169/500 terminado. Recompensa: -200.0, epsilon: 0.429
# Episode 170/500 terminado. Recompensa: -200.0, epsilon: 0.427
# Episode 171/500 terminado. Recompensa: -200.0, epsilon: 0.424
# Episode 172/500 terminado. Recompensa: -200.0, epsilon: 0.422
# Episode 173/500 terminado. Recompensa: -200.0, epsilon: 0.420
# Episode 174/500 terminado. Recompensa: -200.0, epsilon: 0.418
# Episode 175/500 terminado. Recompensa: -200.0, epsilon: 0.416
# Episode 176/500 terminado. Recompensa: -200.0, epsilon: 0.414
# Episode 177/500 terminado. Recompensa: -200.0, epsilon: 0.412
# Episode 178/500 terminado. Recompensa: -200.0, epsilon: 0.410
# Episode 179/500 terminado. Recompensa: -200.0, epsilon: 0.408
# Episode 180/500 terminado. Recompensa: -200.0, epsilon: 0.406
# Episode 181/500 terminado. Recompensa: -200.0, epsilon: 0.404
# Episode 182/500 terminado. Recompensa: -200.0, epsilon: 0.402
# Episode 183/500 terminado. Recompensa: -200.0, epsilon: 0.400
# Episode 184/500 terminado. Recompensa: -200.0, epsilon: 0.398
# Episode 185/500 terminado. Recompensa: -200.0, epsilon: 0.396
# Episode 186/500 terminado. Recompensa: -200.0, epsilon: 0.394
# Episode 187/500 terminado. Recompensa: -200.0, epsilon: 0.392
# Episode 188/500 terminado. Recompensa: -200.0, epsilon: 0.390
# Episode 189/500 terminado. Recompensa: -200.0, epsilon: 0.388
# Episode 190/500 terminado. Recompensa: -200.0, epsilon: 0.386
# Episode 191/500 terminado. Recompensa: -200.0, epsilon: 0.384
# Episode 192/500 terminado. Recompensa: -200.0, epsilon: 0.382
# Episode 193/500 terminado. Recompensa: -200.0, epsilon: 0.380
# Episode 194/500 terminado. Recompensa: -200.0, epsilon: 0.378
# Episode 195/500 terminado. Recompensa: -200.0, epsilon: 0.376
# Episode 196/500 terminado. Recompensa: -200.0, epsilon: 0.374
# Episode 197/500 terminado. Recompensa: -200.0, epsilon: 0.373
# Episode 198/500 terminado. Recompensa: -200.0, epsilon: 0.371
# Episode 199/500 terminado. Recompensa: -200.0, epsilon: 0.369
# Episode 200/500 terminado. Recompensa: -200.0, epsilon: 0.367
# Episode 201/500 terminado. Recompensa: -200.0, epsilon: 0.365
# Episode 202/500 terminado. Recompensa: -200.0, epsilon: 0.363
# Episode 203/500 terminado. Recompensa: -200.0, epsilon: 0.361
# Episode 204/500 terminado. Recompensa: -200.0, epsilon: 0.360
# Episode 205/500 terminado. Recompensa: -200.0, epsilon: 0.358
# Episode 206/500 terminado. Recompensa: -200.0, epsilon: 0.356
# Episode 207/500 terminado. Recompensa: -200.0, epsilon: 0.354
# Episode 208/500 terminado. Recompensa: -200.0, epsilon: 0.353
# Episode 209/500 terminado. Recompensa: -200.0, epsilon: 0.351
# Episode 210/500 terminado. Recompensa: -200.0, epsilon: 0.349
# Episode 211/500 terminado. Recompensa: -200.0, epsilon: 0.347
# Episode 212/500 terminado. Recompensa: -200.0, epsilon: 0.346
# Episode 213/500 terminado. Recompensa: -200.0, epsilon: 0.344
# Episode 214/500 terminado. Recompensa: -200.0, epsilon: 0.342
# Episode 215/500 terminado. Recompensa: -200.0, epsilon: 0.340
# Episode 216/500 terminado. Recompensa: -200.0, epsilon: 0.339
# Episode 217/500 terminado. Recompensa: -200.0, epsilon: 0.337
# Episode 218/500 terminado. Recompensa: -200.0, epsilon: 0.335
# Episode 219/500 terminado. Recompensa: -200.0, epsilon: 0.334
# Episode 220/500 terminado. Recompensa: -200.0, epsilon: 0.332
# Episode 221/500 terminado. Recompensa: -200.0, epsilon: 0.330
# Episode 222/500 terminado. Recompensa: -200.0, epsilon: 0.329
# Episode 223/500 terminado. Recompensa: -200.0, epsilon: 0.327
# Episode 224/500 terminado. Recompensa: -200.0, epsilon: 0.325
# Episode 225/500 terminado. Recompensa: -200.0, epsilon: 0.324
# Episode 226/500 terminado. Recompensa: -200.0, epsilon: 0.322
# Episode 227/500 terminado. Recompensa: -200.0, epsilon: 0.321
# Episode 228/500 terminado. Recompensa: -200.0, epsilon: 0.319
# Episode 229/500 terminado. Recompensa: -200.0, epsilon: 0.317
# Episode 230/500 terminado. Recompensa: -200.0, epsilon: 0.316
# Episode 231/500 terminado. Recompensa: -200.0, epsilon: 0.314
# Episode 232/500 terminado. Recompensa: -200.0, epsilon: 0.313
# Episode 233/500 terminado. Recompensa: -200.0, epsilon: 0.311
# Episode 234/500 terminado. Recompensa: -200.0, epsilon: 0.309
# Episode 235/500 terminado. Recompensa: -200.0, epsilon: 0.308
# Episode 236/500 terminado. Recompensa: -200.0, epsilon: 0.306
# Episode 237/500 terminado. Recompensa: -200.0, epsilon: 0.305
# Episode 238/500 terminado. Recompensa: -200.0, epsilon: 0.303
# Episode 239/500 terminado. Recompensa: -200.0, epsilon: 0.302
# Episode 240/500 terminado. Recompensa: -200.0, epsilon: 0.300
# Episode 241/500 terminado. Recompensa: -200.0, epsilon: 0.299
# Episode 242/500 terminado. Recompensa: -200.0, epsilon: 0.297
# Episode 243/500 terminado. Recompensa: -200.0, epsilon: 0.296
# Episode 244/500 terminado. Recompensa: -200.0, epsilon: 0.294
# Episode 245/500 terminado. Recompensa: -200.0, epsilon: 0.293
# Episode 246/500 terminado. Recompensa: -200.0, epsilon: 0.291
# Episode 247/500 terminado. Recompensa: -200.0, epsilon: 0.290
# Episode 248/500 terminado. Recompensa: -200.0, epsilon: 0.288
# Episode 249/500 terminado. Recompensa: -200.0, epsilon: 0.287
# Episode 250/500 terminado. Recompensa: -200.0, epsilon: 0.286
# Episode 251/500 terminado. Recompensa: -200.0, epsilon: 0.284
# Episode 252/500 terminado. Recompensa: -200.0, epsilon: 0.283
# Episode 253/500 terminado. Recompensa: -200.0, epsilon: 0.281
# Episode 254/500 terminado. Recompensa: -200.0, epsilon: 0.280
# Episode 255/500 terminado. Recompensa: -200.0, epsilon: 0.279
# Episode 256/500 terminado. Recompensa: -200.0, epsilon: 0.277
# Episode 257/500 terminado. Recompensa: -200.0, epsilon: 0.276
# Episode 258/500 terminado. Recompensa: -200.0, epsilon: 0.274
# Episode 259/500 terminado. Recompensa: -200.0, epsilon: 0.273
# Episode 260/500 terminado. Recompensa: -200.0, epsilon: 0.272
# Episode 261/500 terminado. Recompensa: -200.0, epsilon: 0.270
# Episode 262/500 terminado. Recompensa: -200.0, epsilon: 0.269
# Episode 263/500 terminado. Recompensa: -200.0, epsilon: 0.268
# Episode 264/500 terminado. Recompensa: -200.0, epsilon: 0.266
# Episode 265/500 terminado. Recompensa: -200.0, epsilon: 0.265
# Episode 266/500 terminado. Recompensa: -200.0, epsilon: 0.264
# Episode 267/500 terminado. Recompensa: -200.0, epsilon: 0.262
# Episode 268/500 terminado. Recompensa: -200.0, epsilon: 0.261
# Episode 269/500 terminado. Recompensa: -200.0, epsilon: 0.260
# Episode 270/500 terminado. Recompensa: -200.0, epsilon: 0.258
# Episode 271/500 terminado. Recompensa: -200.0, epsilon: 0.257
# Episode 272/500 terminado. Recompensa: -200.0, epsilon: 0.256
# Episode 273/500 terminado. Recompensa: -200.0, epsilon: 0.255
# Episode 274/500 terminado. Recompensa: -200.0, epsilon: 0.253
# Episode 275/500 terminado. Recompensa: -200.0, epsilon: 0.252
# Episode 276/500 terminado. Recompensa: -200.0, epsilon: 0.251
# ...
# Episode 14/500 terminado. Recompensa: -200.0, epsilon: 0.932
# Episode 15/500 terminado. Recompensa: -200.0, epsilon: 0.928
# Episode 16/500 terminado. Recompensa: -200.0, epsilon: 0.923
# Episode 17/500 terminado. Recompensa: -200.0, epsilon: 0.918
# Episode 18/500 terminado. Recompensa: -200.0, epsilon: 0.914
# Episode 19/500 terminado. Recompensa: -200.0, epsilon: 0.909
# Episode 20/500 terminado. Recompensa: -200.0, epsilon: 0.905
# Episode 21/500 terminado. Recompensa: -200.0, epsilon: 0.900
# Episode 22/500 terminado. Recompensa: -200.0, epsilon: 0.896
# Episode 23/500 terminado. Recompensa: -200.0, epsilon: 0.891
# Episode 24/500 terminado. Recompensa: -200.0, epsilon: 0.887
# Episode 25/500 terminado. Recompensa: -200.0, epsilon: 0.882
# Episode 26/500 terminado. Recompensa: -200.0, epsilon: 0.878
# Episode 27/500 terminado. Recompensa: -200.0, epsilon: 0.873
# Episode 28/500 terminado. Recompensa: -200.0, epsilon: 0.869
# Episode 29/500 terminado. Recompensa: -200.0, epsilon: 0.865
# Episode 30/500 terminado. Recompensa: -200.0, epsilon: 0.860
# Episode 31/500 terminado. Recompensa: -200.0, epsilon: 0.856
# Episode 32/500 terminado. Recompensa: -200.0, epsilon: 0.852
# Episode 33/500 terminado. Recompensa: -200.0, epsilon: 0.848
# Episode 34/500 terminado. Recompensa: -200.0, epsilon: 0.843
# Episode 35/500 terminado. Recompensa: -200.0, epsilon: 0.839
# Episode 36/500 terminado. Recompensa: -200.0, epsilon: 0.835
# Episode 37/500 terminado. Recompensa: -200.0, epsilon: 0.831
# Episode 38/500 terminado. Recompensa: -200.0, epsilon: 0.827
# Episode 39/500 terminado. Recompensa: -200.0, epsilon: 0.822
# Episode 40/500 terminado. Recompensa: -200.0, epsilon: 0.818
# Episode 41/500 terminado. Recompensa: -200.0, epsilon: 0.814
# Episode 42/500 terminado. Recompensa: -200.0, epsilon: 0.810
# Episode 43/500 terminado. Recompensa: -200.0, epsilon: 0.806
# Episode 44/500 terminado. Recompensa: -200.0, epsilon: 0.802
# Episode 45/500 terminado. Recompensa: -200.0, epsilon: 0.798
# Episode 46/500 terminado. Recompensa: -200.0, epsilon: 0.794
# Episode 47/500 terminado. Recompensa: -200.0, epsilon: 0.790
# Episode 48/500 terminado. Recompensa: -200.0, epsilon: 0.786
# Episode 49/500 terminado. Recompensa: -200.0, epsilon: 0.782
# Episode 50/500 terminado. Recompensa: -200.0, epsilon: 0.778
# Episode 51/500 terminado. Recompensa: -200.0, epsilon: 0.774
# Episode 52/500 terminado. Recompensa: -200.0, epsilon: 0.771
# Episode 53/500 terminado. Recompensa: -200.0, epsilon: 0.767
# Episode 54/500 terminado. Recompensa: -200.0, epsilon: 0.763
# Episode 55/500 terminado. Recompensa: -200.0, epsilon: 0.759
# Episode 56/500 terminado. Recompensa: -200.0, epsilon: 0.755
# Episode 57/500 terminado. Recompensa: -200.0, epsilon: 0.751
# Episode 58/500 terminado. Recompensa: -200.0, epsilon: 0.748
# Episode 59/500 terminado. Recompensa: -200.0, epsilon: 0.744
# Episode 60/500 terminado. Recompensa: -200.0, epsilon: 0.740
# Episode 61/500 terminado. Recompensa: -200.0, epsilon: 0.737
# Episode 62/500 terminado. Recompensa: -200.0, epsilon: 0.733
# Episode 63/500 terminado. Recompensa: -200.0, epsilon: 0.729
# Episode 64/500 terminado. Recompensa: -200.0, epsilon: 0.726
# Episode 65/500 terminado. Recompensa: -200.0, epsilon: 0.722
# Episode 66/500 terminado. Recompensa: -200.0, epsilon: 0.718
# Episode 67/500 terminado. Recompensa: -200.0, epsilon: 0.715
# Episode 68/500 terminado. Recompensa: -200.0, epsilon: 0.711
# Episode 69/500 terminado. Recompensa: -200.0, epsilon: 0.708
# Episode 70/500 terminado. Recompensa: -200.0, epsilon: 0.704
# Episode 71/500 terminado. Recompensa: -200.0, epsilon: 0.701
# Episode 72/500 terminado. Recompensa: -200.0, epsilon: 0.697
# Episode 73/500 terminado. Recompensa: -200.0, epsilon: 0.694
# Episode 74/500 terminado. Recompensa: -200.0, epsilon: 0.690
# Episode 75/500 terminado. Recompensa: -200.0, epsilon: 0.687
# Episode 76/500 terminado. Recompensa: -200.0, epsilon: 0.683
# Episode 77/500 terminado. Recompensa: -200.0, epsilon: 0.680
# Episode 78/500 terminado. Recompensa: -200.0, epsilon: 0.676
# Episode 79/500 terminado. Recompensa: -200.0, epsilon: 0.673
# Episode 80/500 terminado. Recompensa: -200.0, epsilon: 0.670
# Episode 81/500 terminado. Recompensa: -200.0, epsilon: 0.666
# Episode 82/500 terminado. Recompensa: -200.0, epsilon: 0.663
# Episode 83/500 terminado. Recompensa: -200.0, epsilon: 0.660
# Episode 84/500 terminado. Recompensa: -200.0, epsilon: 0.656
# Episode 85/500 terminado. Recompensa: -200.0, epsilon: 0.653
# Episode 86/500 terminado. Recompensa: -200.0, epsilon: 0.650
# Episode 87/500 terminado. Recompensa: -200.0, epsilon: 0.647
# Episode 88/500 terminado. Recompensa: -200.0, epsilon: 0.643
# Episode 89/500 terminado. Recompensa: -200.0, epsilon: 0.640
# Episode 90/500 terminado. Recompensa: -200.0, epsilon: 0.637
# Episode 91/500 terminado. Recompensa: -200.0, epsilon: 0.634
# Episode 92/500 terminado. Recompensa: -200.0, epsilon: 0.631
# Episode 93/500 terminado. Recompensa: -200.0, epsilon: 0.627
# Episode 94/500 terminado. Recompensa: -200.0, epsilon: 0.624
# Episode 95/500 terminado. Recompensa: -200.0, epsilon: 0.621
# Episode 96/500 terminado. Recompensa: -200.0, epsilon: 0.618
# Episode 97/500 terminado. Recompensa: -200.0, epsilon: 0.615
# Episode 98/500 terminado. Recompensa: -200.0, epsilon: 0.612
# Episode 99/500 terminado. Recompensa: -200.0, epsilon: 0.609
# Episode 100/500 terminado. Recompensa: -200.0, epsilon: 0.606
# Episode 101/500 terminado. Recompensa: -200.0, epsilon: 0.603
# Episode 102/500 terminado. Recompensa: -200.0, epsilon: 0.600
# Episode 103/500 terminado. Recompensa: -200.0, epsilon: 0.597
# Episode 104/500 terminado. Recompensa: -200.0, epsilon: 0.594
# Episode 105/500 terminado. Recompensa: -200.0, epsilon: 0.591
# Episode 106/500 terminado. Recompensa: -200.0, epsilon: 0.588
# Episode 107/500 terminado. Recompensa: -200.0, epsilon: 0.585
# Episode 108/500 terminado. Recompensa: -200.0, epsilon: 0.582
# Episode 109/500 terminado. Recompensa: -200.0, epsilon: 0.579
# Episode 110/500 terminado. Recompensa: -200.0, epsilon: 0.576
# Episode 111/500 terminado. Recompensa: -200.0, epsilon: 0.573
# Episode 112/500 terminado. Recompensa: -200.0, epsilon: 0.570
# Episode 113/500 terminado. Recompensa: -200.0, epsilon: 0.568
# Episode 114/500 terminado. Recompensa: -200.0, epsilon: 0.565
# Episode 115/500 terminado. Recompensa: -200.0, epsilon: 0.562
# Episode 116/500 terminado. Recompensa: -200.0, epsilon: 0.559
# Episode 117/500 terminado. Recompensa: -200.0, epsilon: 0.556
# Episode 118/500 terminado. Recompensa: -200.0, epsilon: 0.554
# Episode 119/500 terminado. Recompensa: -200.0, epsilon: 0.551
# Episode 120/500 terminado. Recompensa: -200.0, epsilon: 0.548
# Episode 121/500 terminado. Recompensa: -200.0, epsilon: 0.545
# Episode 122/500 terminado. Recompensa: -200.0, epsilon: 0.543
# Episode 123/500 terminado. Recompensa: -200.0, epsilon: 0.540
# Episode 124/500 terminado. Recompensa: -200.0, epsilon: 0.537
# Episode 125/500 terminado. Recompensa: -200.0, epsilon: 0.534
# Episode 126/500 terminado. Recompensa: -200.0, epsilon: 0.532
# Episode 127/500 terminado. Recompensa: -200.0, epsilon: 0.529
# Episode 128/500 terminado. Recompensa: -200.0, epsilon: 0.526
# Episode 129/500 terminado. Recompensa: -200.0, epsilon: 0.524
# Episode 130/500 terminado. Recompensa: -200.0, epsilon: 0.521
# Episode 131/500 terminado. Recompensa: -200.0, epsilon: 0.519
# Episode 132/500 terminado. Recompensa: -200.0, epsilon: 0.516
# Episode 133/500 terminado. Recompensa: -200.0, epsilon: 0.513
# Episode 134/500 terminado. Recompensa: -200.0, epsilon: 0.511
# Episode 135/500 terminado. Recompensa: -200.0, epsilon: 0.508
# Episode 136/500 terminado. Recompensa: -200.0, epsilon: 0.506
# Episode 137/500 terminado. Recompensa: -200.0, epsilon: 0.503
# Episode 138/500 terminado. Recompensa: -200.0, epsilon: 0.501
# Episode 139/500 terminado. Recompensa: -200.0, epsilon: 0.498
# Episode 140/500 terminado. Recompensa: -200.0, epsilon: 0.496
# Episode 141/500 terminado. Recompensa: -200.0, epsilon: 0.493
# Episode 142/500 terminado. Recompensa: -200.0, epsilon: 0.491
# Episode 143/500 terminado. Recompensa: -200.0, epsilon: 0.488
# Episode 144/500 terminado. Recompensa: -200.0, epsilon: 0.486
# Episode 145/500 terminado. Recompensa: -200.0, epsilon: 0.483
# Episode 146/500 terminado. Recompensa: -200.0, epsilon: 0.481
# Episode 147/500 terminado. Recompensa: -200.0, epsilon: 0.479
# Episode 148/500 terminado. Recompensa: -200.0, epsilon: 0.476
# Episode 149/500 terminado. Recompensa: -200.0, epsilon: 0.474
# Episode 150/500 terminado. Recompensa: -200.0, epsilon: 0.471
# Episode 151/500 terminado. Recompensa: -200.0, epsilon: 0.469
# Episode 152/500 terminado. Recompensa: -200.0, epsilon: 0.467
# Episode 153/500 terminado. Recompensa: -200.0, epsilon: 0.464
# Episode 154/500 terminado. Recompensa: -200.0, epsilon: 0.462
# Episode 155/500 terminado. Recompensa: -200.0, epsilon: 0.460
# Episode 156/500 terminado. Recompensa: -200.0, epsilon: 0.458
# Episode 157/500 terminado. Recompensa: -200.0, epsilon: 0.455
# Episode 158/500 terminado. Recompensa: -200.0, epsilon: 0.453
# Episode 159/500 terminado. Recompensa: -200.0, epsilon: 0.451
# Episode 160/500 terminado. Recompensa: -200.0, epsilon: 0.448
# Episode 161/500 terminado. Recompensa: -200.0, epsilon: 0.446
# Episode 162/500 terminado. Recompensa: -200.0, epsilon: 0.444
# Episode 163/500 terminado. Recompensa: -200.0, epsilon: 0.442
# Episode 164/500 terminado. Recompensa: -200.0, epsilon: 0.440
# Episode 165/500 terminado. Recompensa: -200.0, epsilon: 0.437
# Episode 166/500 terminado. Recompensa: -200.0, epsilon: 0.435
# Episode 167/500 terminado. Recompensa: -200.0, epsilon: 0.433
# Episode 168/500 terminado. Recompensa: -200.0, epsilon: 0.431
# Episode 169/500 terminado. Recompensa: -200.0, epsilon: 0.429
# Episode 170/500 terminado. Recompensa: -200.0, epsilon: 0.427
# Episode 171/500 terminado. Recompensa: -200.0, epsilon: 0.424
# Episode 172/500 terminado. Recompensa: -200.0, epsilon: 0.422
# Episode 173/500 terminado. Recompensa: -200.0, epsilon: 0.420
# Episode 174/500 terminado. Recompensa: -200.0, epsilon: 0.418
# Episode 175/500 terminado. Recompensa: -200.0, epsilon: 0.416
# Episode 176/500 terminado. Recompensa: -200.0, epsilon: 0.414
# Episode 177/500 terminado. Recompensa: -200.0, epsilon: 0.412
# Episode 178/500 terminado. Recompensa: -200.0, epsilon: 0.410
# Episode 179/500 terminado. Recompensa: -200.0, epsilon: 0.408
# Episode 180/500 terminado. Recompensa: -200.0, epsilon: 0.406
# Episode 181/500 terminado. Recompensa: -200.0, epsilon: 0.404
# Episode 182/500 terminado. Recompensa: -200.0, epsilon: 0.402
# Episode 183/500 terminado. Recompensa: -200.0, epsilon: 0.400
# Episode 184/500 terminado. Recompensa: -200.0, epsilon: 0.398
# Episode 185/500 terminado. Recompensa: -200.0, epsilon: 0.396
# Episode 186/500 terminado. Recompensa: -200.0, epsilon: 0.394
# Episode 187/500 terminado. Recompensa: -200.0, epsilon: 0.392
# Episode 188/500 terminado. Recompensa: -200.0, epsilon: 0.390
# Episode 189/500 terminado. Recompensa: -200.0, epsilon: 0.388
# Episode 190/500 terminado. Recompensa: -200.0, epsilon: 0.386
# Episode 191/500 terminado. Recompensa: -200.0, epsilon: 0.384
# Episode 192/500 terminado. Recompensa: -200.0, epsilon: 0.382
# Episode 193/500 terminado. Recompensa: -200.0, epsilon: 0.380
# Episode 194/500 terminado. Recompensa: -200.0, epsilon: 0.378
# Episode 195/500 terminado. Recompensa: -200.0, epsilon: 0.376
# Episode 196/500 terminado. Recompensa: -200.0, epsilon: 0.374
# Episode 197/500 terminado. Recompensa: -200.0, epsilon: 0.373
# Episode 198/500 terminado. Recompensa: -200.0, epsilon: 0.371
# Episode 199/500 terminado. Recompensa: -200.0, epsilon: 0.369
# Episode 200/500 terminado. Recompensa: -200.0, epsilon: 0.367
# Episode 201/500 terminado. Recompensa: -200.0, epsilon: 0.365
# Episode 202/500 terminado. Recompensa: -200.0, epsilon: 0.363
# Episode 203/500 terminado. Recompensa: -200.0, epsilon: 0.361
# Episode 204/500 terminado. Recompensa: -200.0, epsilon: 0.360
# Episode 205/500 terminado. Recompensa: -200.0, epsilon: 0.358
# Episode 206/500 terminado. Recompensa: -200.0, epsilon: 0.356
# Episode 207/500 terminado. Recompensa: -200.0, epsilon: 0.354
# Episode 208/500 terminado. Recompensa: -200.0, epsilon: 0.353
# Episode 209/500 terminado. Recompensa: -200.0, epsilon: 0.351
# Episode 210/500 terminado. Recompensa: -200.0, epsilon: 0.349
# Episode 211/500 terminado. Recompensa: -200.0, epsilon: 0.347
# Episode 212/500 terminado. Recompensa: -200.0, epsilon: 0.346
# Episode 213/500 terminado. Recompensa: -200.0, epsilon: 0.344
# Episode 214/500 terminado. Recompensa: -200.0, epsilon: 0.342
# Episode 215/500 terminado. Recompensa: -200.0, epsilon: 0.340
# Episode 216/500 terminado. Recompensa: -200.0, epsilon: 0.339
# Episode 217/500 terminado. Recompensa: -200.0, epsilon: 0.337
# Episode 218/500 terminado. Recompensa: -200.0, epsilon: 0.335
# Episode 219/500 terminado. Recompensa: -200.0, epsilon: 0.334
# Episode 220/500 terminado. Recompensa: -200.0, epsilon: 0.332
# Episode 221/500 terminado. Recompensa: -200.0, epsilon: 0.330
# Episode 222/500 terminado. Recompensa: -200.0, epsilon: 0.329
# Episode 223/500 terminado. Recompensa: -200.0, epsilon: 0.327
# Episode 224/500 terminado. Recompensa: -200.0, epsilon: 0.325
# Episode 225/500 terminado. Recompensa: -200.0, epsilon: 0.324
# Episode 226/500 terminado. Recompensa: -200.0, epsilon: 0.322
# Episode 227/500 terminado. Recompensa: -200.0, epsilon: 0.321
# Episode 228/500 terminado. Recompensa: -200.0, epsilon: 0.319
# Episode 229/500 terminado. Recompensa: -200.0, epsilon: 0.317
# Episode 230/500 terminado. Recompensa: -200.0, epsilon: 0.316
# Episode 231/500 terminado. Recompensa: -200.0, epsilon: 0.314
# Episode 232/500 terminado. Recompensa: -200.0, epsilon: 0.313
# Episode 233/500 terminado. Recompensa: -200.0, epsilon: 0.311
# Episode 234/500 terminado. Recompensa: -200.0, epsilon: 0.309
# Episode 235/500 terminado. Recompensa: -200.0, epsilon: 0.308
# Episode 236/500 terminado. Recompensa: -200.0, epsilon: 0.306
# Episode 237/500 terminado. Recompensa: -200.0, epsilon: 0.305
# Episode 238/500 terminado. Recompensa: -200.0, epsilon: 0.303
# Episode 239/500 terminado. Recompensa: -200.0, epsilon: 0.302
# Episode 240/500 terminado. Recompensa: -200.0, epsilon: 0.300
# Episode 241/500 terminado. Recompensa: -200.0, epsilon: 0.299
# Episode 242/500 terminado. Recompensa: -200.0, epsilon: 0.297
# Episode 243/500 terminado. Recompensa: -200.0, epsilon: 0.296
# Episode 244/500 terminado. Recompensa: -200.0, epsilon: 0.294
# Episode 245/500 terminado. Recompensa: -200.0, epsilon: 0.293
# Episode 246/500 terminado. Recompensa: -200.0, epsilon: 0.291
# Episode 247/500 terminado. Recompensa: -200.0, epsilon: 0.290
# Episode 248/500 terminado. Recompensa: -200.0, epsilon: 0.288
# Episode 249/500 terminado. Recompensa: -200.0, epsilon: 0.287
# Episode 250/500 terminado. Recompensa: -200.0, epsilon: 0.286
# Episode 251/500 terminado. Recompensa: -200.0, epsilon: 0.284
# Episode 252/500 terminado. Recompensa: -200.0, epsilon: 0.283
# Episode 253/500 terminado. Recompensa: -200.0, epsilon: 0.281
# Episode 254/500 terminado. Recompensa: -200.0, epsilon: 0.280
# Episode 255/500 terminado. Recompensa: -200.0, epsilon: 0.279
# Episode 256/500 terminado. Recompensa: -200.0, epsilon: 0.277
# Episode 257/500 terminado. Recompensa: -200.0, epsilon: 0.276
# Episode 258/500 terminado. Recompensa: -200.0, epsilon: 0.274
# Episode 259/500 terminado. Recompensa: -200.0, epsilon: 0.273
# Episode 260/500 terminado. Recompensa: -200.0, epsilon: 0.272
# Episode 261/500 terminado. Recompensa: -200.0, epsilon: 0.270
# Episode 262/500 terminado. Recompensa: -200.0, epsilon: 0.269
# Episode 263/500 terminado. Recompensa: -200.0, epsilon: 0.268
# Episode 264/500 terminado. Recompensa: -200.0, epsilon: 0.266
# Episode 265/500 terminado. Recompensa: -200.0, epsilon: 0.265
# Episode 266/500 terminado. Recompensa: -200.0, epsilon: 0.264
# Episode 267/500 terminado. Recompensa: -200.0, epsilon: 0.262
# Episode 268/500 terminado. Recompensa: -200.0, epsilon: 0.261
# Episode 269/500 terminado. Recompensa: -200.0, epsilon: 0.260
# Episode 270/500 terminado. Recompensa: -200.0, epsilon: 0.258
# Episode 271/500 terminado. Recompensa: -200.0, epsilon: 0.257
# Episode 272/500 terminado. Recompensa: -200.0, epsilon: 0.256
